# %% [markdown]
# This is a collaborative group project done at the end of Phase 4 of Moringa School's Data Science program. The team members of this group include:
#
# - [Esther Nyaikuba](nyaikuba.esther@gmail.com)
# - [Clara Gatambia](https://github.com/claragatambia)
# - [Lewis Gitari](https://github.com/GitariLewis)
# - [Rhoda](rhondsy@gmail.com)
# - [Mark Kuria](kuriamark@gmail.com)

# %% [markdown]
# Acoording to a research by https://fitsmallbusiness.com/real-estate-statistics/ out of 100 people in USA 69 are home owners, out of the 100 homebuyers 29 are new home owners. The real estate market in the USA is dynamic and influenced by numerous factors such as economic factors, location, demographic trends, interest rates, and seasons. Accurately predicting real estate market trends is a necessity for various market players including investors, developers, real estate agencies and homeowners to make informed decisions regarding property investments, pricing, location and market timing.The many variables can make the process tedious for the market players. We intend to create a predictive time series model that will help to determine the top five favourite zipcodes .
#
# 1. Visualize  the effect 2008 recession on the housing market per ZipCode.
#
# 2. Investigate and establish the 5 best ZipCodes  to invest in that offer a consistent good Return on investment.
#
# 3. Visualize the appreciation of the real estate industry in high population  Zipcodes.
#
# 4. Build a time series regression modell to predict the average house prices in the US.

# %% [markdown]
# <style>
# .attractive-cell {
#     padding: 20px;
#     color: white;
#     font-size: 16px;
#     text-align: center;
#     border-radius: 10px;
#     overflow: hidden;
#     background-image: linear-gradient(120deg, #ff6b6b, #4361ee);
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
# }
# </style>
# <div class="Import libraries">
#     <h1>Import necessary Libraries</h1>
#
# </div>

# %% [markdown]
# These libraries help us in performing data manipulation, visualizing distributions and performing forecasts.

# %%
# Importing necessary libraries
# Basics
import pandas as pd
import numpy as np
import itertools
from io import StringIO

# Visualization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns
import matplotlib.patches as mpatches
from matplotlib.pylab import rcParams
import time

# Modeling libraries
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf, pacf, adfuller
from sklearn.linear_model import LassoLarsCV
from sklearn.model_selection import TimeSeriesSplit
from prophet import Prophet
import joblib
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### <b> <span style='color:#16C2D5'>|</span>Defining custom classes/Functions</b>
#
# In line with the concepts of OOP, custom classes were created to speed up the opening and manipulation of data in this project. They are as follows:

# %%
def missing_data(input_data):
    '''
    This function returns a DataFrame with information about the percentage of nulls in each column
    and the column data type.

    input: pandas DataFrame
    output: pandas DataFrame
    '''

    total = input_data.isnull().sum()
    percent = (input_data.isnull().sum() / input_data.isnull().count() * 100)
    table = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])

    types = []
    for col in input_data.columns:
        dtype = str(input_data[col].dtype)
        types.append(dtype)
    table["Types"] = types

    # Filter to include only columns with missing values
    table = table[table['Total'] > 0]

    return table

# %%
# Function to plot the bar plots
def plot_barplot(dataframe,x,y,x_title,y_title):
  fig,ax = plt.subplots(figsize=(10,5))

  sns.barplot(data = dataframe,x=x, y=y,orient='h',errorbar=None)
  ax.set_title(f"{y_title} vs {x_title}")
  ax.set_xlabel(x_title)
  ax.set_ylabel(y_title)
  plt.show()

# Function to plot histograms
def plot_histogram(dataframe, x, y, x_title, y_title):
  fig, ax = plt.subplots(figsize=(10, 5))

  sns.histplot(data=dataframe, x=x, y=y, kde=True)
  ax.set_title(f"{y_title} vs {x_title}")
  ax.set_xlabel(x_title)
  ax.set_ylabel(y_title)
  plt.show()

# Function to plot boxplots
def plot_boxplot(dataframe,x,y,x_title,y_title):
  fig,ax = plt.subplots(figsize=(10,5))

  sns.boxplot(data = dataframe,x=x, y=y)
  ax.set_title(f"{y_title} vs {x_title}")
  ax.set_xlabel(x_title)
  ax.set_ylabel(y_title)
  plt.xticks(rotation=90)
  plt.show()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> Data Understanding</span></b> </div>

# %% [markdown]
# In this section after the loading the data, we seek to find a brief overview of the data. This includes:
# * the data information.
# * The data distribution(shape)
# * Check for missing values.

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Reading data</b>

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',100)
df = pd.read_csv('zillow_data.csv')

# %% [markdown]
# The `df.head()` function is used to get a rough look at a few of the records in the dataframe to understand the data better.

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0         1  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 1         2  235700.0  236900.0  236700.0  235400.0  233300.0  230600.0
# 2         3  210400.0  212200.0  212200.0  210700.0  208300.0  205500.0
# 3         4  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 4         5   77300.0   77300.0   77300.0   77300.0   77400.0   77500.0
#
#     1996-10   1996-11   1996-12   1997-01   1997-02   1997-03   1997-04  \
# 0  340400.0  341300.0  342600.0  344400.0  345700.0  346700.0  347800.0
# 1  227300.0  223400.0  219600.0  215800.0  211100.0  205700.0  200900.0
# 2  202500.0  199800.0  198300.0  197300.0  195400.0  193000.0  191800.0
# 3  505300.0  504200.0  503600.0  503400.0  502200.0  500000.0  497900.0
# 4   77600.0   77700.0   77700.0   77800.0   77900.0   77900.0   77800.0
#
#     1997-05   1997-06   1997-07   1997-08   1997-09   1997-10   1997-11  \
# 0  349000.0  350400.0  352000.0  353900.0  356200.0  358800.0  361800.0
# 1  196800.0  193600.0  191400.0  190400.0  190800.0  192700.0  196000.0
# 2  191800.0  193000.0  195200.0  198400.0  202800.0  208000.0  213800.0
# 3  496300.0  495200.0  494700.0  494900.0  496200.0  498600.0  502000.0
# 4   77800.0   77800.0   77800.0   77800.0   77900.0   78100.0   78200.0
#
#     1997-12   1998-01   1998-02   1998-03   1998-04   1998-05   1998-06  \
# 0  365700.0  370200.0  374700.0  378900.0  383500.0  388300.0  393300.0
# 1  201300.0  207400.0  212200.0  214600.0  215100.0  213400.0  210200.0
# 2  220700.0  227500.0  231800.0  233400.0  233900.0  233500.0  233300.0
# 3  507600.0  514900.0  522200.0  529500.0  537900.0  546900.0  556400.0
# 4   78400.0   78600.0   78800.0   79000.0   79100.0   79200.0   79300.0
#
#     1998-07   1998-08   1998-09   1998-10   1998-11   1998-12   1999-01  \
# 0  398500.0  403800.0  409100.0  414600.0  420100.0  426200.0  432600.0
# 1  206100.0  202100.0  198800.0  196100.0  194100.0  193400.0  193400.0
1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %% [markdown]
# The `df.info()` and `df.dtypes` functions are both called to give a rough understanding of the dataframe, and the types of data held in each column. Normally, `df.info()` would be sufficient, but due to the sheer number of columns in the dataframe, that information isn't displayed. Thus, `df.dtypes` is called.

# %% [markdown]
# As expected, all the columns representing time-series data will be storing either an integer or a float data type. It is also important to note that the `RegionID` & `RegionName` are stored as integers - to ensure they are unique - and the remaining 5 columns all contain strings.
#
# The shape of the dataframe was observed as follows:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: float64(219), int64(49), object(4)
# memory usage: 30.6+ MB

# %%
# Checking the data types by looping and grouping similar data types
dtype_groups = {}
for column, dtype in df.dtypes.items():
    if dtype not in dtype_groups:
        dtype_groups[dtype] = [column]
    else:
        dtype_groups[dtype].append(column)

# Printing grouped data types with distinct format
for dtype, columns in dtype_groups.items():
    print(f"Data type: {dtype}")
    print("Columns:")
    print(', '.join(columns))
    print("="*50)  # Separator for better readability
# Out:
# Data type: int64
# Columns:
# RegionID, RegionName, SizeRank, 2014-07, 2014-08, 2014-09, 2014-10, 2014-11, 2014-12, 2015-01, 2015-02, 2015-03, 2015-04, 2015-05, 2015-06, 2015-07, 2015-08, 2015-09, 2015-10, 2015-11, 2015-12, 2016-01, 2016-02, 2016-03, 2016-04, 2016-05, 2016-06, 2016-07, 2016-08, 2016-09, 2016-10, 2016-11, 2016-12, 2017-01, 2017-02, 2017-03, 2017-04, 2017-05, 2017-06, 2017-07, 2017-08, 2017-09, 2017-10, 2017-11, 2017-12, 2018-01, 2018-02, 2018-03, 2018-04
# ==================================================
# Data type: object
# Columns:
# City, State, Metro, CountyName
# ==================================================
# Data type: float64
# Columns:
# 1996-04, 1996-05, 1996-06, 1996-07, 1996-08, 1996-09, 1996-10, 1996-11, 1996-12, 1997-01, 1997-02, 1997-03, 1997-04, 1997-05, 1997-06, 1997-07, 1997-08, 1997-09, 1997-10, 1997-11, 1997-12, 1998-01, 1998-02, 1998-03, 1998-04, 1998-05, 1998-06, 1998-07, 1998-08, 1998-09, 1998-10, 1998-11, 1998-12, 1999-01, 1999-02, 1999-03, 1999-04, 1999-05, 1999-06, 1999-07, 1999-08, 1999-09, 1999-10, 1999-11, 1999-12, 2000-01, 2000-02, 2000-03, 2000-04, 2000-05, 2000-06, 2000-07, 2000-08, 2000-09, 2000-10, 2000-11, 2000-12, 2001-01, 2001-02, 2001-03, 2001-04, 2001-05, 2001-06, 2001-07, 2001-08, 2001-09, 2001-10, 2001-11, 2001-12, 2002-01, 2002-02, 2002-03, 2002-04, 2002-05, 2002-06, 2002-07, 2002-08, 2002-09, 2002-10, 2002-11, 2002-12, 2003-01, 2003-02, 2003-03, 2003-04, 2003-05, 2003-06, 2003-07, 2003-08, 2003-09, 2003-10, 2003-11, 2003-12, 2004-01, 2004-02, 2004-03, 2004-04, 2004-05, 2004-06, 2004-07, 2004-08, 2004-09, 2004-10, 2004-11, 2004-12, 2005-01, 2005-02, 2005-03, 2005-04, 2005-05, 2005-06, 2005-07, 2005-08, 2005-09, 2005-10, 2005-11, 2005-12, 2006-01, 2006-02, 2006-03, 2006-04, 2006-05, 2006-06, 2006-07, 2006-08, 2006-09, 2006-10, 2006-11, 2006-12, 2007-01, 2007-02, 2007-03, 2007-04, 2007-05, 2007-06
# 2000-10   1036  7.036609  float64
# 2000-11   1036  7.036609  float64
# 2000-12   1036  7.036609  float64
# 2001-01   1036  7.036609  float64
# 2001-02   1036  7.036609  float64
# 2001-03   1036  7.036609  float64
# 2001-04   1036  7.036609  float64
# 2001-05   1036  7.036609  float64
# 2001-06   1036  7.036609  float64
# 2001-07   1036  7.036609  float64
# 2001-08   1036  7.036609  float64
# 2001-09   1036  7.036609  float64
# 2001-10   1036  7.036609  float64
# 2001-11   1036  7.036609  float64
# 2001-12   1036  7.036609  float64
# 2002-01   1036  7.036609  float64
# 2002-02   1036  7.036609  float64
# 2002-03   1036  7.036609  float64
# 2002-04   1036  7.036609  float64
# 2002-05   1036  7.036609  float64
# 2002-06   1036  7.036609  float64
# 2002-07   1036  7.036609  float64
# 2002-08   1036  7.036609  float64
# 2002-09   1036  7.036609  float64
# 2002-10   1036  7.036609  float64
# 2002-11   1036  7.036609  float64
# 2002-12   1036  7.036609  float64
# 2003-01   1036  7.036609  float64
# 2003-02   1036  7.036609  float64
# 2003-03   1036  7.036609  float64
# 2003-04   1036  7.036609  float64
# 2003-05   1036  7.036609  float64
# 2003-06   1036  7.036609  float64
# 2003-07    918  6.235142  float64
# 2003-08    918  6.235142  float64
# 2003-09    918  6.235142  float64
# 2003-10    918  6.235142  float64
# 2003-11    918  6.235142  float64
# 2003-12    918  6.235142  float64
# 2004-01    887  6.024587  float64
# 2004-02    887  6.024587  float64
# 2004-03    887  6.024587  float64
# 2004-04    887  6.024587  float64
# 2004-05    887  6.024587  float64
# 2004-06    887  6.024587  float64
# 2004-07    866  5.881953  float64
# 2004-08    866  5.881953  float64
# 2004-09    866  5.881953  float64
# 2004-10    866  5.881953  float64
# 2004-11    866  5.881953  float64
# 2004-12    866  5.881953  float64
# 2005-01    814  5.528765  float64
# 2005-02    814  5.528765  float64
# 2005-03    801  5.440467  float64
# 2005-04    801  5.440467  float64
# 2005-05    801  5.440467  float64
# 2005-06    801  5.440467  float64
# 2005-07    723  4.910684  float64
# 2005-08    723  4.910684  float64
# 2005-09    723  4.910684  float64
# 2005-10    723  4.910684  float64
# 2005-11    723  4.910684  float64
# 2005-12    723  4.910684  float64
# 2006-01    667  4.530327  float64
# 2006-02    667  4.530327  float64
# 2006-03    667  4.530327  float64
# 2006-04    667  4.530327  float64
# 2006-05    667  4.530327  float64
# 2006-06    667  4.530327  float64
# 2006-07    640  4.346940  float64
# 2006-08    640  4.346940  float64
# 2006-09    640  4.346940  float64
# 2006-10    640  4.346940  float64
# 2006-11    640  4.346940  float64
# 2006-12    640  4.346940  float64
# 2007-01    620  4.211098  float64
# 2007-02    620  4.211098  float64
# 2007-03    620  4.211098  float64
# 2007-04    620  4.211098  float64
# 2007-05    620  4.211098  float64
# 2007-06    620  4.211098  float64
# 2007-07    613  4.163554  float64
# 2007-08    613  4.163554  float64
# 2007-09    613  4.163554  float64
# 2007-10    613  4.163554  float64
# 2007-11    613  4.163554  float64
# 2007-12    613  4.163554  float64
# 2008-01    607  4.122801  float64
# 2008-02    607  4.122801  float64
# 2008-03    607  4.122801  float64
# 2008-04    607  4.122801  float64
# 2008-05    607  4.122801  float64
# 2008-06    607  4.122801  float64
# 2008-07    598  4.061672  float64
# 2008-08    598  4.061672  float64
# 2008-09    598  4.061672  float64
# 2008-10    598  4.061672  float64
# 2008-11    598  4.061672  float64
# 2008-12    598  4.061672  float64
# 2009-01    587  3.986959  float64
# 2009-02    587  3.986959  float64
# 2009-03    587  3.986959  float64
# 2009-04    587  3.986959  float64
# 2009-05    587  3.986959  float64
# 2009-06    587  3.986959  float64
# 2009-07    580  3.939415  float64
# 2009-08    580  3.939415  float64
# 2009-09    580  3.939415  float64
# 2009-10    580  3.939415  float64
# 2009-11    580  3.939415  float64
# 2009-12    580  3.939415  float64
# 2010-01    579  3.932622  float64
# 2010-02    579  3.932622  float64
# 2010-03    349  2.370441  float64
# 2010-04    349  2.370441  float64
# 2010-05    349  2.370441  float64
# 2010-06    349  2.370441  float64
# 2010-07    308  2.091965  float64
# 2010-08    308  2.091965  float64
# 2010-09    308  2.091965  float64
# 2010-10    308  2.091965  float64
# 2010-11    308  2.091965  float64
# 2010-12    308  2.091965  float64
# 2011-01    275  1.867826  float64
# 2011-02    275  1.867826  float64
# 2011-03    275  1.867826  float64
# 2011-04    275  1.867826  float64
# 2011-05    275  1.867826  float64
# 2011-06    275  1.867826  float64
# 2011-07    251  1.704816  float64
# 2011-08    251  1.704816  float64
# 2011-09    251  1.704816  float64
# 2011-10    251  1.704816  float64
# 2011-11    251  1.704816  float64
# 2011-12    251  1.704816  float64
# 2012-01    224  1.521429  float64
# 2012-02    224  1.521429  float64
# 2012-03    224  1.521429  float64
# 2012-04    224  1.521429  float64
# 2012-05    224  1.521429  float64
# 2012-06    224  1.521429  float64
# 2012-07    206  1.399171  float64
# 2012-08    206  1.399171  float64
# 2012-09    206  1.399171  float64
# 2012-10    206  1.399171  float64
# 2012-11    206  1.399171  float64
# 2012-12    206  1.399171  float64
# 2013-01    151  1.025606  float64
# 2013-02    151  1.025606  float64
# 2013-03    151  1.025606  float64
# 2013-04    151  1.025606  float64
# 2013-05    151  1.025606  float64
# 2013-06    151  1.025606  float64
# 2013-07    109  0.740338  float64
# 2013-08    109  0.740338  float64
# 2013-09    109  0.740338  float64
# 2013-10    109  0.740338  float64
# 2013-11    109  0.740338  float64
# 2013-12    109  0.740338  float64
# 2014-01     56  0.380357  float64
# 2014-02     56  0.380357  float64
# 2014-03     56  0.380357  float64
# 2014-04     56  0.380357  float64
# 2014-05     56  0.380357  float64
# 2014-06     56  0.380357  float64

# %% [markdown]
# 1.   Okay, Metro column is the only object column with null values.
# 2.   We are a working with a volatile dataset in that, nill values in our case are actually creating a trend in itselfeven without deep investigation.Notice how the nill values are constant for a period the as time goes by they decrease steadily.
# We'll leave the data as it is.

# %%
# Check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The dataframe has 14723 rows and 272 columns. Majority of those columns represent numerical values. The first seven columns - `RegionID`, `RegionName`, `City`, `State`, `Metro`, `CountyName` and `SizeRank` - are the columns that give us more information about the dataset.
#
# Our interpratation:
# - *RegionID*: The unique ID of the region.
# - *RegionName*: The name of the region..
# - *City*: The name of the city.
# - *State*: The state in which the RegionID is found.
# - *Metro*: The metropolitan name within which the RegionID is found.
# - *CountyName*: The name of the county within a given region.
# - *SizeRank*: The region's area organised in descending order.

# %%
#Split the data into descriptive and the timeseries columns for easy processsing.

# %%
# ['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName','SizeRank']

descriptive_col = df.columns[:7]
descriptive_col
# Out:
# Index(['RegionID', 'RegionName', 'City', 'State', 'Metro', 'CountyName',
#        'SizeRank'],
#       dtype='object')

# %%
timeseries_col = df.columns[-265:]
timeseries_col
# Out:
# Index(['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09',
#        '1996-10', '1996-11', '1996-12', '1997-01',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=265)

# %% [markdown]
# The last 265 columns all need to be datetime columns.

# %% [markdown]
# <style>
# .attractive-cell {
#     padding: 20px;
#     color: grey;
#     font-size: 16px;
#     text-align: center;
#     border-radius: 10px;
#     overflow: hidden;
#     background-image: linear-gradient(120deg, #ff6b6b, #4361ee);
#     box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
# }
# </style>
# <div class="attractive-cell">
#     <h1>Data preprocessing</h1>
#
# </div>

# %%
# Checking the data types by looping and grouping similar data types
dtype_groups = {}
for column, dtype in df.dtypes.items():
    if dtype not in dtype_groups:
        dtype_groups[dtype] = [column]
    else:
        dtype_groups[dtype].append(column)

# Printing grouped data types with distinct format
for dtype, columns in dtype_groups.items():
    print(f"Data type: {dtype}")
    print("Columns:")
    print(', '.join(columns))
    print("="*50)  # Separator for better readability
# Out:
# Data type: int64
# Columns:
# RegionID, RegionName, SizeRank, 2014-07, 2014-08, 2014-09, 2014-10, 2014-11, 2014-12, 2015-01, 2015-02, 2015-03, 2015-04, 2015-05, 2015-06, 2015-07, 2015-08, 2015-09, 2015-10, 2015-11, 2015-12, 2016-01, 2016-02, 2016-03, 2016-04, 2016-05, 2016-06, 2016-07, 2016-08, 2016-09, 2016-10, 2016-11, 2016-12, 2017-01, 2017-02, 2017-03, 2017-04, 2017-05, 2017-06, 2017-07, 2017-08, 2017-09, 2017-10, 2017-11, 2017-12, 2018-01, 2018-02, 2018-03, 2018-04
# ==================================================
# Data type: object
# Columns:
# City, State, Metro, CountyName
# ==================================================
# Data type: float64
# Columns:
# 1996-04, 1996-05, 1996-06, 1996-07, 1996-08, 1996-09, 1996-10, 1996-11, 1996-12, 1997-01, 1997-02, 1997-03, 1997-04, 1997-05, 1997-06, 1997-07, 1997-08, 1997-09, 1997-10, 1997-11, 1997-12, 1998-01, 1998-02, 1998-03, 1998-04, 1998-05, 1998-06, 1998-07, 1998-08, 1998-09, 1998-10, 1998-11, 1998-12, 1999-01, 1999-02, 1999-03, 1999-04, 1999-05, 1999-06, 1999-07, 1999-08, 1999-09, 1999-10, 1999-11, 1999-12, 2000-01, 2000-02, 2000-03, 2000-04, 2000-05, 2000-06, 2000-07, 2000-08, 2000-09, 2000-10, 2000-11, 2000-12, 2001-01, 2001-02, 2001-03, 2001-04, 2001-05, 2001-06, 2001-07, 2001-08, 2001-09, 2001-10, 2001-11, 2001-12, 2002-01, 2002-02, 2002-03, 2002-04, 2002-05, 2002-06, 2002-07, 2002-08, 2002-09, 2002-10, 2002-11, 2002-12, 2003-01, 2003-02, 2003-03, 2003-04, 2003-05, 2003-06, 2003-07, 2003-08, 2003-09, 2003-10, 2003-11, 2003-12, 2004-01, 2004-02, 2004-03, 2004-04, 2004-05, 2004-06, 2004-07, 2004-08, 2004-09, 2004-10, 2004-11, 2004-12, 2005-01, 2005-02, 2005-03, 2005-04, 2005-05, 2005-06, 2005-07, 2005-08, 2005-09, 2005-10, 2005-11, 2005-12, 2006-01, 2006-02, 2006-03, 2006-04, 2006-05, 2006-06, 2006-07, 2006-08, 2006-09, 2006-10, 2006-11, 2006-12, 2007-01, 2007-02, 2007-03, 2007-04, 2007-05, 2007-06, 2007-07, 2007-08, 2007-09, 2007-10, 2007-11, 2007-12, 2008-01, 2008-02, 2008-03, 2008-04, 2008-05, 2008-06, 2008-07, 2008-08, 2008-09, 2008-10, 2008-11, 2008-12, 2009-01, 2009-02, 2009-03, 2009-04, 2009-05, 2009-06, 2009-07, 2009-08, 2009-09, 2009-10, 2009-11, 2009-12, 2010-01, 2010-02, 2010-03, 2010-04, 2010-05, 2010-06, 2010-07, 2010-08, 2010-09, 2010-10, 2010-11, 2010-12, 2011-01, 2011-02, 2011-03, 2011-04, 2011-05, 2011-06, 2011-07, 2011-08, 2011-09, 2011-10, 2011-11, 2011-12, 2012-01, 2012-02, 2012-03, 2012-04, 2012-05, 2012-06, 2012-07, 2012-08, 2012-09, 2012-10, 2012-11, 2012-12, 2013-01, 2013-02, 2013-03, 2013-04, 2013-05, 2013-06, 2013-07, 2013-08, 2013-09, 2013-10, 2013-11, 2013-12, 2014-01, 2014-02, 2014-03, 2014-04, 2014-05, 2014-06
# ==================================================

# %%
metro_dist = df[['State', 'RegionID','RegionName','City','Metro','CountyName','SizeRank']].groupby("State").count().sort_values(by='Metro',
                                                                                                                   ascending=False).head(10)
metro_dist
# Out:
#        RegionID  RegionName  City  Metro  CountyName  SizeRank
# State
# CA         1224        1224  1224   1182        1224      1224
# NY         1015        1015  1015    963        1015      1015
# TX          989         989   989    873         989       989
# PA          831         831   831    816         831       831
# FL          785         785   785    758         785       785
# OH          588         588   588    570         588       588
# IL          547         547   547    537         547       547
# NJ          502         502   502    502         502       502
# MI          499         499   499    457         499       499
# MA          417         417   417    416         417       417

# %% [markdown]
# Let's categorize the data by the state vs the total properties.

# %%
df_states= df[['State', 'RegionID']].groupby(
    "State").count().sort_values(by='RegionID', ascending=False)
df_states.reset_index(inplace=True)
df_states.rename(columns={'RegionID': 'Count of Properties'}, inplace=True)
df_states.head(20)
# Out:
#    State  Count of Properties
# 0     CA                 1224
# 1     NY                 1015
# 2     TX                  989
# 3     PA                  831
# 4     FL                  785
# 5     OH                  588
# 6     IL                  547
# 7     NJ                  502
# 8     MI                  499
# 9     IN                  428
# 10    NC                  428
# 11    MA                  417
# 12    TN                  404
# 13    VA                  401
# 14    MN                  375
# 15    GA                  345
# 16    WA                  341
# 17    WI                  332
# 18    MO                  319
# 19    MD                  317

# %% [markdown]
# California (CA) is seen to have the most listings with 1224, followed closely by New York, NY (1015) and Texas, TX (989). Vermont (VT), Washington DC (DC) and San Diego (SD) have the least listings at 16, 18 and 19 respectively.

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'>  Feature Engineering</span></b> </div>

# %% [markdown]
# A feature which will seem obvious but very important in real estate is ROI. A figurewhich will illustrate percentage gain of a listing.We'll compare the initial listing of the property visa vis the latest price.
#
# The last column is the latest price since its the latest price recorded.The first column is the first non-nill price recorded.

# %%
# Create a copy of the original model to engineer new features
df2= df.copy()

# Loop through the columns
for index, row in df2.iterrows():
  # Establishing the last price of the property
  last_price = df2.columns[271]

  # Establishing the initial price of the property
  initial_price = 0

  # Loop through time_series_cols to find the first non-null value
  for col in timeseries_col:
      initial_price = df2[col].values[index]
      if not pd.isnull(initial_price):
        break
  df2.at[index, 'Initial Price'] = initial_price

  df2['Last Price'] = df[last_price]

  df2['ROI (%)'] = round(
      (((df2['Last Price'] / df2['Initial Price']) - 1) * 100), 2)

df2.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0         1  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 1         2  235700.0  236900.0  236700.0  235400.0  233300.0  230600.0
# 2         3  210400.0  212200.0  212200.0  210700.0  208300.0  205500.0
# 3         4  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 4         5   77300.0   77300.0   77300.0   77300.0   77400.0   77500.0
#
#     1996-10   1996-11   1996-12   1997-01   1997-02   1997-03   1997-04  \
# 0  340400.0  341300.0  342600.0  344400.0  345700.0  346700.0  347800.0
# 1  227300.0  223400.0  219600.0  215800.0  211100.0  205700.0  200900.0
# 2  202500.0  199800.0  198300.0  197300.0  195400.0  193000.0  191800.0
# 3  505300.0  504200.0  503600.0  503400.0  502200.0  500000.0  497900.0
# 4   77600.0   77700.0   77700.0   77800.0   77900.0   77900.0   77800.0
#
#     1997-05   1997-06   1997-07   1997-08   1997-09   1997-10   1997-11  \
# 0  349000.0  350400.0  352000.0  353900.0  356200.0  358800.0  361800.0
# 1  196800.0  193600.0  191400.0  190400.0  190800.0  192700.0  196000.0
# 2  191800.0  193000.0  195200.0  198400.0  202800.0  208000.0  213800.0
# 3  496300.0  495200.0  494700.0  494900.0  496200.0  498600.0  502000.0
# 4   77800.0   77800.0   77800.0   77800.0   77900.0   78100.0   78200.0
#
#     1997-12   1998-01   1998-02   1998-03   1998-04   1998-05   1998-06  \
# 0  365700.0  370200.0  374700.0  378900.0  383500.0  388300.0  393300.0
# 1  201300.0  207400.0  212200.0  214600.0  215100.0  213400.0  210200.0
# 2  220700.0  227500.0  231800.0  233400.0  233900.0  233500.0  233300.0
# 3  507600.0  514900.0  522200.0  529500.0  537900.0  546900.0  556400.0
# 4   78400.0   78600.0   78800.0   79000.0   79100.0   79200.0   79300.0
#
#     1998-07   1998-08   1998-09   1998-10   1998-11   1998-12   1999-01  \
# 0  398500.0  403800.0  409100.0  414600.0  420100.0  426200.0  432600.0
# 1  206100.0  202100.0  198800.0  196100.0  194100.0  193400.0  193400.0
# 3  1308500  1307000       498100.0     1307000   162.40
# 4   121000   121500        77300.0      121500    57.18
#
# [5 rows x 275 columns]

# %%
#Now we have succesfully added a column with ROI% value for properties
ROI_df = df2.sort_values(by='ROI (%)', ascending=False)
ROI_df.tail(10)
# Out:
#        RegionID  RegionName            City State            Metro  \
# 3175      71589       31601        Valdosta    GA         Valdosta
# 14465     85878       63036  French Village    MO       Farmington
# 14527     79367       48760      Silverwood    MI              NaN
# 4381      79244       48503           Flint    MI            Flint
# 4149      79247       48506           Flint    MI            Flint
# 5191      71547       31520       Brunswick    GA        Brunswick
# 13440     79884       49713     Boyne Falls    MI              NaN
# 11932     64987       17252       St Thomas    PA     Chambersburg
# 9067      64974       17236      Montgomery    PA     Chambersburg
# 14441     67444       22937          Esmont    VA  Charlottesville
#
#            CountyName  SizeRank  1996-04  1996-05  1996-06  1996-07  1996-08  \
# 3175          Lowndes      3176      NaN      NaN      NaN      NaN      NaN
# 14465  Saint Francois     14466      NaN      NaN      NaN      NaN      NaN
# 14527         Tuscola     14528      NaN      NaN      NaN      NaN      NaN
# 4381          Genesee      4382  47100.0  47200.0  47400.0  47600.0  47900.0
# 4149          Genesee      4150  46000.0  46400.0  46800.0  47200.0  47700.0
# 5191            Glynn      5192      NaN      NaN      NaN      NaN      NaN
# 13440      Charlevoix     13441      NaN      NaN      NaN      NaN      NaN
# 11932        Franklin     11933      NaN      NaN      NaN      NaN      NaN
# 9067         Franklin      9068      NaN      NaN      NaN      NaN      NaN
# 14441       Albemarle     14442      NaN      NaN      NaN      NaN      NaN
#
#        1996-09  1996-10  1996-11  1996-12  1997-01  1997-02  1997-03  1997-04  \
# 3175       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14465      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14527      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4381   48300.0  48700.0  49100.0  49600.0  50200.0  50800.0  51400.0  51900.0
# 4149   48100.0  48700.0  49200.0  49900.0  50600.0  51300.0  51900.0  52500.0
# 5191       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 13440      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11932      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9067       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14441      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        1997-05  1997-06  1997-07  1997-08  1997-09  1997-10  1997-11  1997-12  \
# 3175       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14465      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14527      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4381   52400.0  52800.0  53000.0  53300.0  53400.0  53500.0  53700.0  53900.0
# 4149   53000.0  53400.0  53700.0  54000.0  54200.0  54300.0  54500.0  54600.0
# 5191       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 13440      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11932      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9067       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14441      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        1998-01  1998-02  1998-03  1998-04  1998-05  1998-06  1998-07  1998-08  \
# 3175       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14465      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14527      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4381   54200.0  54500.0  55000.0  55400.0  55900.0  56300.0  56700.0  56800.0
# 4149   54800.0  54900.0  54900.0  54900.0  54900.0  54800.0  54600.0  54400.0
# 5191       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 13440      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11932      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9067       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14441      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        1998-09  1998-10  1998-11  1998-12  1999-01  1999-02  1999-03  1999-04  \
# 3175       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14465      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14527      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4381   56800.0  56600.0  56100.0  55400.0  54600.0  53800.0  53100.0  52500.0
# 4149   54000.0  53500.0  52800.0  52000.0  51100.0  50200.0  49400.0  48800.0
# 5191       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 13440      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 11932      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 9067       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 14441      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#
017-04  2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  \
# 3175     42800    42600    42900    43000    43000    42700    42300    42500
# 14465    96100    95300    95000    94500    92100    88000    85800    86200
# 14527    27800    27800    27700    26900    26400    27000    29100    30400
# 4381     17800    17300    17300    17600    18200    18900    19700    20600
# 4149     19100    20000    20700    20700    20900    21200    21800    22100
# 5191     53100    52500    52500    53000    53200    53100    53000    52600
# 13440    95900    96300    97000    98300   101700   107000   111000   112400
# 11932   148000   148800   148600   147500   147300   148400   150200   151600
# 9067    151000   151600   152500   153100   153800   155000   155600   156300
# 14441   148400   150600   153700   155200   156100   156500   156000   156100
#
#        2017-11  2017-12  2018-01  2018-02  2018-03  2018-04  Initial Price  \
# 3175     43500    44500    44900    46100    48500    50500        88300.0
# 14465    86500    86700    88300    90700    92800    94400       181700.0
# 14527    31000    31200    31000    29100    27100    26300        52300.0
# 4381     21000    20800    20500    20800    21700    22800        47100.0
# 4149     22200    22200    21600    21200    21300    21500        46000.0
# 5191     52500    53400    54700    56000    58200    60100       129600.0
# 13440   113700   115600   117800   119300   119300   118000       257700.0
# 11932   152500   151600   151000   151100   150700   149300       330100.0
# 9067    157100   157900   158300   158600   158600   158800       415100.0
# 14441   157700   158200   156500   155700   156500   156200       435400.0
#
#        Last Price  ROI (%)
# 3175        50500   -42.81
# 14465       94400   -48.05
# 14527       26300   -49.71
# 4381        22800   -51.59
# 4149        21500   -53.26
# 5191        60100   -53.63
# 13440      118000   -54.21
# 11932      149300   -54.77
# 9067       158800   -61.74
# 14441      156200   -64.12
#
# [10 rows x 275 columns]

# %%
ROI_df = df2.sort_values(by='ROI (%)', ascending=False)
ROI_df.head(10)
# Out:
#        RegionID  RegionName         City State  \
# 117       62022       11211     New York    NY
# 1155      62033       11222     New York    NY
# 475       62027       11216     New York    NY
# 191       60639        7302  Jersey City    NJ
# 106       62026       11215     New York    NY
# 13864     62320       11975    Wainscott    NY
# 11728     62281       11930   Amagansett    NY
# 14217     93399       80449      Hartsel    CO
# 1790      96127       90291  Los Angeles    CA
# 258       66125       20001   Washington    DC
#
#                                 Metro            CountyName  SizeRank  \
# 117                          New York                 Kings       118
# 1155                         New York                 Kings      1156
# 475                          New York                 Kings       476
# 191                          New York                Hudson       192
# 106                          New York                 Kings       107
# 13864                        New York               Suffolk     13865
# 11728                        New York               Suffolk     11729
# 14217                          Denver                  Park     14218
# 1790   Los Angeles-Long Beach-Anaheim           Los Angeles      1791
# 258                        Washington  District of Columbia       259
#
#         1996-04   1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  \
# 117    133200.0  132900.0  132500.0  132200.0  131800.0  131600.0  131500.0
# 1155   149200.0  148400.0  147500.0  146600.0  146000.0  145600.0  145400.0
# 475    146100.0  146600.0  147200.0  147700.0  148400.0  149300.0  150200.0
# 191    137200.0  137800.0  138500.0  139100.0  139600.0  140100.0  140700.0
# 106    225700.0  227500.0  229400.0  231600.0  234100.0  236900.0  239800.0
# 1155   1721100       149200.0     1721100  1053.55
# 475    1598700       146100.0     1598700   994.25
# 191    1427300       137200.0     1427300   940.31
# 106    2243900       225700.0     2243900   894.20
# 13864  3467800       349500.0     3467800   892.22
# 11728  3141100       328400.0     3141100   856.49
# 14217   267700        30000.0      267700   792.33
# 1790   2056800       234300.0     2056800   777.85
# 258     793300        92000.0      793300   762.28
#
# [10 rows x 275 columns]

# %%
# impressive, we have ROI's as high as over 300% but some properties listed had a negative ROI.

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Normalization and Scaling</b>
#
# Having gone through the data, on comparing the different columns, there is need for scaling to improve our model perfomance by eliminating strong bias on large figures.

# %% [markdown]
# We'll create a new dataframe  which  will contain the melted data. This will convert the original dataframe `df` from wide to long format. This will be done by applying the custom function `melt_data`

# %%
def melt_data(df2):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.
    Returns a long-form datetime dataframe
    with the datetime column names as the index and the values as the 'values' column.

    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """

    melted = pd.melt(df2, id_vars=['RegionName', 'RegionID', 'SizeRank',
                     'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna()

    # Aggregate values if multiple rows exist for the same datetime
    melted = melted.groupby(['time', 'RegionName', 'RegionID', 'SizeRank',
                             'City', 'State', 'Metro', 'CountyName'])['value'].mean().reset_index()

    return melted

# %%
# Function to convert data from wide to long formart.
def melt_data(df2):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.
    Returns a long-form datetime dataframe
    with the datetime column names as the index and the values as the 'values' column.

    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """

    melted = pd.melt(df, id_vars=['RegionName', 'RegionID', 'SizeRank',
                     'City', 'State', 'Metro', 'CountyName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna()
    return melted

# %% [markdown]
# Converting the dataframe to long format:

# %%
# Create a variable to hold the long-format data
df_melted = melt_data(df)
df_melted.head(7)
# Out:
#    RegionName  RegionID  SizeRank      City State              Metro  \
# 0       60657     84654         1   Chicago    IL            Chicago
# 1       75070     90668         2  McKinney    TX  Dallas-Fort Worth
# 2       77494     91982         3      Katy    TX            Houston
# 3       60614     84616         4   Chicago    IL            Chicago
# 4       79936     93144         5   El Paso    TX            El Paso
# 5       77084     91733         6   Houston    TX            Houston
# 6       10467     61807         7  New York    NY           New York
#
#   CountyName       time     value
# 0       Cook 1996-04-01  334200.0
# 1     Collin 1996-04-01  235700.0
# 2     Harris 1996-04-01  210400.0
# 3       Cook 1996-04-01  498100.0
# 4    El Paso 1996-04-01   77300.0
# 5     Harris 1996-04-01   95000.0
# 6      Bronx 1996-04-01  152900.0

# %%
time_vaule_counts = df_melted['time'].value_counts
print(time_vaule_counts)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df_melted.shape
# Out:
# (3508681, 9)

# %%
# Engineer new features for the month and year.
df_melted['Year'] = df_melted['time'].dt.year
df_melted['Month'] = df_melted['time'].dt.month

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> Explorative Data Analysis(Visualization)</span></b> </div>

# %% [markdown]
# This section involves visualizing of the different trends, most importantly we'll capture the effects of the housing market crash and analyzing the best performing markets.
# We'll also show the property distribution across different regions.
#
# The years considered to analyze the market trends during the crisis are **2008, 2009 and 2010**.
#
# The years to consider in analyzing the bounce back rates after the crisis are **2011, 2012, 2013, 2014 and 2015**.

# %%
# Use the function to plot bar plots.

df_states20 = df_states.head(20)

plt.figure(figsize=(10, 8))
sns.barplot(data=df_states20, y='State', x='Count of Properties')
plt.title("Top 20 cities with the highest number of households")
plt.xlabel("Count of Properties")
plt.ylabel("State")
plt.show()

# %% [markdown]
# The State of California, New York and Texas have the highest number of property distributions.
#
# Let's see the counties and states and their respective properties distribution.

# %%
plot_barplot(dataframe=df[['RegionID', 'CountyName']].groupby('CountyName').count().reset_index().sort_values(
    by='RegionID', ascending=False).head(10), y='CountyName', x='RegionID', y_title='Counties In USA', x_title='County Properties Distribution')

# %%
plot_barplot(dataframe=df[['RegionID', 'CountyName']].groupby('CountyName').count().reset_index().sort_values(
    by='RegionID', ascending=False).tail(), y='CountyName', x='RegionID', y_title='Counties In USA', x_title='County Properties Distribution')

# %%
#The lowest listing per county was 1 property.

# %%
# Apply the barplot function to get property distribution accross cities.
plot_barplot(dataframe=df[['RegionID', 'City']].groupby('City').count().reset_index().sort_values(
    by='RegionID', ascending=False).head(10), y='City', x='RegionID', y_title='City In USA', x_title='City Properties distribution')

# %%
# Group data by metro and region name so as to get a view of average worth in a specific zipcode.
metro_value = pd.DataFrame(df_melted.groupby(['Metro','RegionName'])['value'].agg('mean').sort_values(ascending=False).head(10))
metro_value
# Out:
#                                                   value
# Metro                          RegionName
# New York                       10021       1.285427e+07
#                                10011       7.755844e+06
#                                10014       6.836902e+06
#                                10128       5.085436e+06
# San Francisco                  94027       3.487129e+06
# Glenwood Springs               81611       3.147124e+06
# Los Angeles-Long Beach-Anaheim 90210       2.789977e+06
# Miami-Fort Lauderdale          33480       2.634498e+06
# San Francisco                  94123       2.630977e+06
# Brunswick                      31561       2.403194e+06

# %% [markdown]
# **New york metropolitan has 4 zipcodes categorized to be having the most valuable properties listed.**

# %%
#why don't we check  out the lowest too?
metro_value = pd.DataFrame(df_melted.groupby(['Metro','RegionName'])['value'].agg('mean').sort_values(ascending=False).tail(10))
metro_value
# Out:
#                                                value
# Metro                       RegionName
# Tulsa                       74030       28101.132075
#                             74110       27110.566038
# Reading                     19602       26036.981132
# Oklahoma City               73129       25691.320755
# Louisville/Jefferson County 40210       25436.842105
# Nashville                   37137       25389.056604
# Miami                       74339       23512.075472
# Madisonville                42410       22089.433962
# Dayton                      45406       20846.875000
# Memphis                     72331       19866.792453

# %% [markdown]
# **Memphis metropitan seems to have the lowest average value of property listed**

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Average house prices by state</b>
# This is done using the groupby function on the house values.

# %%
# Average of listed properties prices by state
state_group = df_melted.groupby('State')['value'].agg('mean').sort_values(ascending=False).head(10)

sns.barplot(data=state_group.reset_index(), x='State', y='value')
# Out:
# <Axes: xlabel='State', ylabel='value'>

# %%
#Analyze distribution of properties per city.
group_cities = pd.DataFrame(df_melted.groupby('City')['value'].agg('mean').sort_values(ascending=False)).head(10)

sns.barplot(data=group_cities.reset_index(), x='City', y='value')
plt.title("Top ten cities with property listings")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Market crash analysis</b>
# The housing market crash of 2008 had a significant impact on U.S. housing prices, causing them to plummet. In the years leading up to the crash, housing prices had risen sharply, fueled by a speculative housing market and easy access to credit. However, when the subprime mortgage crisis hit and defaults began to soar, the bubble burst and housing prices fell dramatically.
#
# We'll focus on the zipcodes that are high value and see the effect on the prices.

# %%
# Analysis of market crash crisis on regions.
high_value_regions = [10021, 10011, 10014, 10128, 94027, 81611, 90210, 33480, 94123, 31561,
                   94115, 94109, 81615, 90402, 92067, 90020, 94028, 94301, 7620, 92657,
                   94022, 94957, 93108, 11217, 94305, 2116, 90265, 94133, 11976, 90049]


years = [2006,2007,2008, 2009, 2010]

plt.figure(figsize=(10,5))
filtered_df = df_melted[(df_melted['Year'].isin(years)) & df_melted['RegionName'].isin(high_value_regions)]
group_crisis = pd.DataFrame(filtered_df.groupby(['RegionName','Year'])['value'].agg('mean').sort_values(ascending=False)).head(12)
sns.barplot(data=group_crisis.reset_index(), x='RegionName', y='value', hue='Year')
plt.title("Average Price distribution of high-value zipcodes during the financial crisis")
plt.show()

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Market crash analysis</b>
# We aim to obtain distribution of house prices in low-end zip codes during the crisis.

# %% [markdown]
# ***We group the zipcodes into two: Low_value & High_value, we'll consider the previous property average value in the different metroplitans as deciphered earlier***

# %%
low_value_regions= [74030,74110,26036,73129,40210,37137,74339,42410,45406,72331]

plt.figure(figsize=(10,5))
filtered_df = df_melted[(df_melted['Year'].isin(years)) & df_melted['RegionName'].isin(low_value_regions)]
group_crisis = pd.DataFrame(filtered_df.groupby(['RegionName','Year'])['value'].agg('mean').sort_values(ascending=False)).head(12)
sns.barplot(data=group_crisis.reset_index(), x='RegionName', y='value', hue='Year')
plt.title("Average Price distribution of low-value zipcodes during the financial crisis")
plt.show()

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Metropolitan growth rates</b>
# Grouping data based on the paercentage difference of past house values using the **pct_change** from pandas.

# %%
df_melted.head()
# Out:
#    RegionName  RegionID  SizeRank      City State              Metro  \
# 0       60657     84654         1   Chicago    IL            Chicago
# 1       75070     90668         2  McKinney    TX  Dallas-Fort Worth
# 2       77494     91982         3      Katy    TX            Houston
# 3       60614     84616         4   Chicago    IL            Chicago
# 4       79936     93144         5   El Paso    TX            El Paso
#
#   CountyName       time     value  Year  Month
# 0       Cook 1996-04-01  334200.0  1996      4
# 1     Collin 1996-04-01  235700.0  1996      4
# 2     Harris 1996-04-01  210400.0  1996      4
# 3       Cook 1996-04-01  498100.0  1996      4
# 4    El Paso 1996-04-01   77300.0  1996      4

# %%
#Function that will be used to call the average value of properties in specific cities in a range of years
def average_value_for_city_year(df, city, years):
    """
    Calculates the average value of properties in a certain city for each year within a specified range.
    """
    # Filter the DataFrame based on the city
    filtered_df = df[df['City'] == city]

    # Initialize an empty dictionary to store results
    result_dict = {'Year': [], 'Average Value': []}

    # Loop through the years in the specified range and calculate the average value for each year
    for year in range(years[0], years[1] + 1):
        average_value = filtered_df[filtered_df['Year'] == year]['value'].mean()
        result_dict['Year'].append(year)
        result_dict['Average Value'].append(average_value)

    # Create a DataFrame from the result dictionary
    result_df = pd.DataFrame(result_dict)

    return result_df

# %% [markdown]
# **let's work with one high value city and one low value city as per our previous classification and see the metropolitan growth trend
# we chose New york as the high value**

# %%
#let's explore the growth pre-market crisis
newyork_average_value = average_value_for_city_year(df_melted, 'New York', years=[1996, 2006])
print(newyork_average_value)
# Out:
#     Year  Average Value
# 0   1996  216966.773504
# 1   1997  224839.102564
# 2   1998  236545.432692
# 3   1999  250879.727564
# 4   2000  274860.897436
# 5   2001  306658.333333
# 6   2002  338789.983974
# 7   2003  393097.607656
# 8   2004  577861.036036
# 9   2005  692566.741071
# 10  2006  771850.372024

# %%
#plot the growth trend
plt.figure(figsize=(10, 6))
plt.plot(newyork_average_value['Year'], newyork_average_value['Average Value'], marker='o', linestyle='-')
plt.title('Average Property Value in New York (2000-2015)')
plt.xlabel('Year')
plt.ylabel('Average Property Value')
plt.grid(True)
plt.xticks(newyork_average_value['Year'], rotation=45)
plt.tight_layout()
plt.show()

# %%
#let's explore the growth post-market crisis
newyork_average_value2 = average_value_for_city_year(df_melted, 'New York', years=[2010, 2018])
print(newyork_average_value2)
# Out:
#    Year  Average Value
# 0  2010   7.693542e+05
# 1  2011   7.754202e+05
# 2  2012   7.686808e+05
# 3  2013   8.118726e+05
# 4  2014   9.218940e+05
# 5  2015   1.035182e+06
# 6  2016   1.097767e+06
# 7  2017   1.160024e+06
# 8  2018   1.186235e+06

# %%
plt.figure(figsize=(10, 6))
plt.plot(newyork_average_value2['Year'], newyork_average_value2['Average Value'], marker='o', linestyle='-')
plt.title('Average Property Value in New York (2010-2018)')
plt.xlabel('Year')
plt.ylabel('Average Property Value')
plt.grid(True)
plt.xticks(newyork_average_value2['Year'], rotation=45)  # Use newyork_average_value2['Year'] here
plt.tight_layout()
plt.show()

# %% [markdown]
# **Let's see how the growth pattern in the metropol that had the lowest value**

# %%
#let's explore the growth post-market crisis
memphis_value = average_value_for_city_year(df_melted, 'Memphis', years=[1996, 2018])
print(memphis_value)
# Out:
#     Year  Average Value
# 0   1996   91349.305556
# 1   1997   94893.229167
# 2   1998   99314.583333
# 3   1999  104577.604167
# 4   2000  110064.583333
# 5   2001  112541.666667
# 6   2002  114221.875000
# 7   2003  116062.500000
# 8   2004  119433.333333
# 9   2005  123833.854167
# 10  2006  127590.625000
# 11  2007  129079.687500
# 12  2008  116309.375000
# 13  2009  101003.645833
# 14  2010  100033.854167
# 15  2011   97997.395833
# 16  2012   96018.229167
# 17  2013   98643.137255
# 18  2014  103598.529412
# 19  2015  106668.627451
# 20  2016  114730.392157
# 21  2017  127071.078431
# 22  2018  134708.823529

# %%
plt.figure(figsize=(10, 6))
plt.plot(memphis_value['Year'], memphis_value['Average Value'], marker='o', linestyle='-')
plt.title('Average Property Value in Mephis (1996-2018)')
plt.xlabel('Year')
plt.ylabel('Average Property Value')
plt.grid(True)
plt.xticks(memphis_value['Year'], rotation=45)  # Use newyork_average_value2['Year'] here
plt.tight_layout()
plt.show()

# %% [markdown]
# **We clearly see the effects of the market crisis in Memphis metropol and the growth trend.**

# %% [markdown]
# # Now let's visualize the Metroplitan growth rates, we'll look at the top and the lowest growth rate across the data set

# %%
# Growth rates of metroplolitan areas.
df_melted['percentage_change'] = df_melted.groupby('Metro')['value'].pct_change() * 100
plt.figure(figsize=(12, 8))
average_percentage_change = pd.DataFrame(df_melted.groupby('Metro')['percentage_change'].mean().sort_values(ascending=False)).head(10)
sns.barplot(data=average_percentage_change.reset_index(), x='Metro', y='percentage_change', palette='viridis')
plt.title("metropolitan growth rates")
plt.xticks(rotation=45)
plt.show()

# %%
df_melted['percentage_change'] = df_melted.groupby('Metro')['value'].pct_change() * 100
plt.figure(figsize=(12, 8))
average_percentage_change = pd.DataFrame(df_melted.groupby('Metro')['percentage_change'].mean().sort_values(ascending=False)).tail(10)
sns.barplot(data=average_percentage_change.reset_index(), x='Metro', y='percentage_change', palette='viridis')
plt.title("metropolitan with the lowest growth rates")
plt.xticks(rotation=45)
plt.show()

# %%
df_melted.head(2)
# Out:
#    RegionName  RegionID  SizeRank      City State              Metro  \
# 0       60657     84654         1   Chicago    IL            Chicago
# 1       75070     90668         2  McKinney    TX  Dallas-Fort Worth
#
#   CountyName       time     value  Year  Month  percentage_change
# 0       Cook 1996-04-01  334200.0  1996      4                NaN
# 1     Collin 1996-04-01  235700.0  1996      4                NaN

# %%
high_value_regions = [10021, 10011, 10014, 10128, 94027, 81611, 90210, 33480, 94123, 31561,
                   94115, 94109, 81615, 90402, 92067, 90020, 94028, 94301, 7620, 92657,
                   94022, 94957, 93108, 11217, 94305, 2116, 90265, 94133, 11976, 90049]

plt.figure(figsize=(12, 8))

# The start date for calculating percentage change
start_date = '2010-01-01'

# Filter the DataFrame to include data from the specified start date onwards
df_filtered = df_melted[df_melted['time'] >= start_date]
df_filtered = df_filtered[df_filtered['RegionID'].isin(high_value_regions)]
# Calculate percentage change and average percentage change
df_filtered['percentage_change'] = df_filtered.groupby('RegionID')['value'].pct_change() * 100
average_percentage_change = pd.DataFrame(df_filtered.groupby('RegionID')['percentage_change'].mean().sort_values(ascending=False)).tail(10)

# Bar plot
sns.barplot(data=average_percentage_change.reset_index(), x='RegionID', y='percentage_change', palette='magma')

# title and labels
plt.title("Growth rate in high_value region post crisis")
plt.xlabel('ZIP CODES')
plt.ylabel('Average Percentage Change')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Post crisis growth rate analysis.</b>
# **What was the growth rate post crisis?**
#
#
#
# **What were the best and worst performing metro's?**

# %%
plt.figure(figsize=(12, 8))

# The start date for calculating percentage change
start_date = '2010-01-01'

# Filter the DataFrame to include data from the specified start date onwards
df_filtered = df_melted[df_melted['time'] >= start_date]

# Calculate percentage change and average percentage change
df_filtered['percentage_change'] = df_filtered.groupby('Metro')['value'].pct_change() * 100
average_percentage_change = pd.DataFrame(df_filtered.groupby('Metro')['percentage_change'].mean().sort_values(ascending=False)).head(10)

# Bar plot
sns.barplot(data=average_percentage_change.reset_index(), x='Metro', y='percentage_change', palette='magma')

# title and labels
plt.title("Metropolitan Areas with the Highest Growth Rates")
plt.xlabel('Metropolitan Area')
plt.ylabel('Average Percentage Change')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %%
plt.figure(figsize=(12, 8))

# The start date for calculating percentage change
start_date = '2010-01-01'

# Filter the DataFrame to include data from the specified start date onwards
df_filtered = df_melted[df_melted['time'] >= start_date]

# Calculate percentage change and average percentage change
df_filtered['percentage_change'] = df_filtered.groupby('Metro')['value'].pct_change() * 100
average_percentage_change = pd.DataFrame(df_filtered.groupby('Metro')['percentage_change'].mean().sort_values(ascending=False)).tail(10)

# Bar plot
sns.barplot(data=average_percentage_change.reset_index(), x='Metro', y='percentage_change', palette='magma')

# title and labels
plt.title("Metropolitan Areas with the Lowest Growth Rates")
plt.xlabel('Metropolitan Area')
plt.ylabel('Average Percentage Change')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show plot
plt.show()

# %% [markdown]
# ### <b> <span style='color:#16C2D5'>|</span> EDA Conclusion</b>

# %% [markdown]
# * California Metro has the highest number of properties listed.
# * ZipCodes **10021, 10011, 10014** and **10128** were among the top priced regions, which apparently were among the Zipcodes less affected by the 2008 financial crisis.
# * Memphis had the lowest valuable property listed.
# * Property pre-categorized among the high value ZipCodes were not greatly affected by the market crisis unlike the drop in value observed post crisis in the low value ZipCodes
# * Post-crisis growth rate is still positive for the high value ZipCodes despite seeing growth rates even went into negatives for some Metro's

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 3. Modelling </span></b> </div>

# %% [markdown]
# By understanding the patterns, trends, and seasonal variations within the data, time series models enable us to make informed predictions about future values.
#  Since most time series data always has the component of trend and sesonality, ARIMA models have the idea of differencing to ensure stationarity.
#
#
# We seek out to build a  model to predict the house prices for the **ZipCodes** which are high priced and have good prospects for  a good **Return on Investment**. We chose the ZIPCODE as a baseline as it is the lowest geographic presentation level in our data
#
# Work plan:
# * Data transformation
# * Data Resampling
# * Baseline model
# * Arima Models
# * Facebook Prophet(ETL pipeline)

# %%
# Copy the melted df for easy workability.
df = df_melted.copy()

# %% [markdown]
# Setting the time as the index column simplifies resampling and data slicing. With the large number of rows resulting from the melting function, training models requires only a fraction of the data to adequately represent the entire population. This approach is essential as models, particularly ARMA models, can be computationally burdensome on very large datasets, lacking efficiency in handling big data.

# %%
df.set_index('time', inplace=True)
df.head()
# Out:
#             RegionName  RegionID  SizeRank         City State        Metro  \
# time
# 1996-04-01        1001     58196      5851       Agawam    MA  Springfield
# 1996-04-01        1002     58197      4200      Amherst    MA  Springfield
# 1996-04-01        1005     58200     11214        Barre    MA    Worcester
# 1996-04-01        1007     58201      6851  Belchertown    MA  Springfield
# 1996-04-01        1008     58202     14548    Blandford    MA  Springfield
#
#            CountyName     value  Year  Month  GrowthRate
# time
# 1996-04-01    Hampden  113100.0  1996      4         NaN
# 1996-04-01  Hampshire  161000.0  1996      4         NaN
# 1996-04-01  Worcester  103100.0  1996      4         NaN
# 1996-04-01  Hampshire  133400.0  1996      4         NaN
# 1996-04-01    Hampden  117500.0  1996      4         NaN

# %% [markdown]
# ### <b> <span style='color:#16C2D5'>|</span> Data Resampling</b>
# Data resampling is a process used in time series analysis to change the frequency of the data observations. It involves aggregating or transforming the data from one time frequency to another, such as from daily to monthly or from hourly to weekly. Resampling can be performed in two main ways: upsampling and downsampling.
#
# The data at our disposal seems to be on a month start basis and that is the best resampling technique for this problem.

# %%
# Resample data on a monthly basis.
#resampling the 'value' column from df to have monthly frequency.
df2= df['value'].resample('MS').mean()
df2.plot()
# Out:
# <Axes: xlabel='time'>

# %% [markdown]
# The plot from the monthly resampled data shows a steady growth from 1999 upto 2007. This was greatly attribute to the high housing mortgages given to low income earners. As from 2008, there is a increasingly staedy drop in the value of houses and this was due to the housing market crash in 2008 This is the period when the **US** had a housing Crisis majorly caused by subprime mortgages, huge debts and low regulation in the financial sector. The value of homes dropped and many home owners and investors could not keep up with their mortgages.
#
# As outlined in [https://www.investopedia.com/articles/economics/09/subprime-market-2008.asp], the US was faced with a financial crisis when the housing syatem collapsed and value of house prices plummuted.

# %%
# Function for the autocorrellation plots
def corr_plots(data):
    acf_diff = plot_acf(data)
    pacf_plot = plot_pacf(data)
    adfttest = adfuller(data)


    return acf_diff, pacf_plot

# %%
corr_plots(df2)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# From the auto-correlation plots, it is very evident that the house value drop between 2008 and 2012 introduced very high seasonality.

# %% [markdown]
# # **BASELINE MODEL**

# %% [markdown]
# Working with the whole data set is impracticle and expensive too soo we'll take the top 30 high value ZIP CODES.

# %%
df_melted.head(2)
# Out:
#    RegionName  RegionID  SizeRank      City State              Metro  \
# 0       60657     84654         1   Chicago    IL            Chicago
# 1       75070     90668         2  McKinney    TX  Dallas-Fort Worth
#
#   CountyName       time     value  Year  Month  percentage_change
# 0       Cook 1996-04-01  334200.0  1996      4                NaN
# 1     Collin 1996-04-01  235700.0  1996      4                NaN

# %%
# Baseline model for forecast of specific zip codes.
high_value_zipcodes = [10021, 10011, 10014, 10128, 94027, 81611, 90210, 33480, 94123, 31561,
                   94115, 94109, 81615, 90402, 92067, 90020, 94028, 94301, 7620, 92657,
                   94022, 94957, 93108, 11217, 94305, 2116, 90265, 94133, 11976, 90049]

# split the time series data into 5 train-test pairs
tsc = TimeSeriesSplit(n_splits=5)

all_train_dates, all_test_dates = [], []
all_train_values, all_test_values = [], []
all_forecasts = []

results_list1 = []

for county in high_value_zipcodes:
    county_data = df_melted[df_melted['RegionName'] == county]

    # Split the data
    dates = county_data.index
    values = county_data['value'].values

    # accumulate values for each fold
    zip_train_dates, zip_test_dates = [], []
    zip_train_values, zip_test_values = [], []

    for train_index, test_index in tsc.split(dates):
        train_dates, test_dates = dates[train_index], dates[test_index]
        train_values, test_values = values[train_index], values[test_index]

        zip_train_dates.extend(train_dates)
        zip_test_dates.extend(test_dates)
        zip_train_values.extend(train_values)
        zip_test_values.extend(test_values)


        baseline_model = ARIMA(train_values, order=(1, 0, 1)).fit()
        forecast = pd.Series(baseline_model.predict(start=len(train_values), end=len(train_values) + 11, typ='levels'))

        print(baseline_model.summary())

        all_forecasts.extend(forecast)


        predicted_value = forecast.iloc[-1]
        real_value = test_values[-1]
        percentage_change = ((predicted_value - real_value) / real_value) * 100
        # Append the forecasted values to the list
        results_list1.append({'County': county, 'Forecast': predicted_value, 'Real': real_value, 'Percentage Change': percentage_change})


results_df = pd.DataFrame(results_list1)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -441.951
# Date:                Sat, 23 Mar 2024   AIC                            891.901
# Time:                        10:08:28   BIC                            897.764
# Sample:                             0   HQIC                           893.844
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.984e+06   1.05e-08   9.47e+14      0.000    9.98e+06    9.98e+06
# ar.L1          0.9828      0.029     33.769      0.000       0.926       1.040
# ma.L1          0.9563      0.371      2.577      0.010       0.229       1.683
# sigma2      6.767e+10   6.17e-12    1.1e+22      0.000    6.77e+10    6.77e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   8.75   Jarque-Bera (JB):                 3.97
# Prob(Q):                              0.00   Prob(JB):                         0.14
# Heteroskedasticity (H):               0.10   Skew:                            -0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.3e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -811.967
# Date:                Sat, 23 Mar 2024   AIC                           1631.934
# Time:                        10:08:28   BIC                           1640.312
# Sample:                             0   HQIC                          1635.211
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.865e+06   4.06e-09   2.43e+15      0.000    9.87e+06    9.87e+06
# ar.L1          0.9892      0.019     51.375      0.000       0.951       1.027
# ma.L1          0.9737      0.231      4.223      0.000       0.522       1.426
# sigma2      4.516e+10   5.44e-12   8.31e+21      0.000    4.52e+10    4.52e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  25.96   Jarque-Bera (JB):                37.59
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.09   Skew:                            -1.53
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.89e+36. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   88
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1179.131
# Date:                Sat, 23 Mar 2024   AIC                           2366.261
# Time:                        10:08:28   BIC                           2376.171
# Sample:                             0   HQIC                          2370.254
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.061e+07   6.94e-10   1.53e+16      0.000    1.06e+07    1.06e+07
# ar.L1          0.9910      0.031     32.363      0.000       0.931       1.051
# ma.L1          0.9804      0.178      5.511      0.000       0.632       1.329
# sigma2      3.676e+10   4.88e-12   7.53e+21      0.000    3.68e+10    3.68e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  44.06   Jarque-Bera (JB):               104.92
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.21   Skew:                            -1.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.21e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  116
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1545.606
# Date:                Sat, 23 Mar 2024   AIC                           3099.212
# Time:                        10:08:28   BIC                           3110.226
# Sample:                             0   HQIC                          3103.683
#                                 - 116
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.086e+07   2.82e-10   3.85e+16      0.000    1.09e+07    1.09e+07
# ar.L1          0.9884      0.020     49.648      0.000       0.949       1.027
# ma.L1          0.9296      0.094      9.896      0.000       0.745       1.114
# sigma2      3.121e+10   1.41e-12   2.21e+22      0.000    3.12e+10    3.12e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  42.56   Jarque-Bera (JB):               120.38
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.24   Skew:                            -1.54
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.54e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1928.342
# Date:                Sat, 23 Mar 2024   AIC                           3864.683
# Time:                        10:08:28   BIC                           3876.563
# Sample:                             0   HQIC                          3869.510
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.172e+07   2.53e-11   4.63e+17      0.000    1.17e+07    1.17e+07
# ar.L1          0.9972      0.006    156.163      0.000       0.985       1.010
# ma.L1          0.9337      0.044     21.377      0.000       0.848       1.019
# sigma2      3.169e+10   1.51e-13    2.1e+23      0.000    3.17e+10    3.17e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  38.00   Jarque-Bera (JB):                62.58
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.92   Skew:                            -0.78
# Prob(H) (two-sided):                  0.76   Kurtosis:                         5.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.34e+39. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   30
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -369.157
# Date:                Sat, 23 Mar 2024   AIC                            746.315
# Time:                        10:08:28   BIC                            751.920
# Sample:                             0   HQIC                           748.108
#                                  - 30
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.368e+06   5.34e+05      8.175      0.000    3.32e+06    5.41e+06
# ar.L1          0.9842      0.086     11.392      0.000       0.815       1.154
# ma.L1          0.9755      0.470      2.076      0.038       0.054       1.897
# sigma2      2.734e+09     13.309   2.05e+08      0.000    2.73e+09    2.73e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.73   Jarque-Bera (JB):                 1.20
# Prob(Q):                              0.00   Prob(JB):                         0.55
# Heteroskedasticity (H):               1.14   Skew:                            -0.23
# Prob(H) (two-sided):                  0.84   Kurtosis:                         2.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  1e+25. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   56
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -688.491
# Date:                Sat, 23 Mar 2024   AIC                           1384.982
# Time:                        10:08:28   BIC                           1393.084
# Sample:                             0   HQIC                          1388.123
#                                  - 56
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.084e+06   1.02e-08   4.97e+14      0.000    5.08e+06    5.08e+06
# ar.L1          0.9968      0.020     50.422      0.000       0.958       1.036
# ma.L1          0.9745      0.436      2.233      0.026       0.119       1.830
# sigma2      3.571e+09    9.8e-11   3.65e+19      0.000    3.57e+09    3.57e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  22.70   Jarque-Bera (JB):                 3.06
# Prob(Q):                              0.00   Prob(JB):                         0.22
# Heteroskedasticity (H):               0.75   Skew:                            -0.52
# Prob(H) (two-sided):                  0.54   Kurtosis:                         2.54
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.07e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   82
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1013.478
# Date:                Sat, 23 Mar 2024   AIC                           2034.955
# Time:                        10:08:29   BIC                           2044.582
# Sample:                             0   HQIC                          2038.821
#                                  - 82
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        5.59e+06   2.94e-10    1.9e+16      0.000    5.59e+06    5.59e+06
# ar.L1          0.9975      0.010     96.400      0.000       0.977       1.018
# ma.L1          0.9007      0.061     14.710      0.000       0.781       1.021
# sigma2      3.531e+09    1.5e-12   2.35e+21      0.000    3.53e+09    3.53e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  12.84   Jarque-Bera (JB):                10.23
# Prob(Q):                              0.00   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.52   Skew:                            -0.79
# Prob(H) (two-sided):                  0.28   Kurtosis:                         3.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.27e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  108
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1359.902
# Date:                Sat, 23 Mar 2024   AIC                           2727.804
# Time:                        10:08:29   BIC                           2738.532
# Sample:                             0   HQIC                          2732.154
#                                 - 108
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        6.12e+06   2.39e-11   2.56e+17      0.000    6.12e+06    6.12e+06
# ar.L1          0.9983      0.011     88.479      0.000       0.976       1.020
# ma.L1          0.8355      0.057     14.784      0.000       0.725       0.946
# sigma2      6.005e+09    6.2e-13   9.69e+21      0.000       6e+09       6e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   7.98   Jarque-Bera (JB):                 4.42
# Prob(Q):                              0.00   Prob(JB):                         0.11
# Heteroskedasticity (H):               3.09   Skew:                            -0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.47e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  134
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1701.874
# Date:                Sat, 23 Mar 2024   AIC                           3411.747
# Time:                        10:08:29   BIC                           3423.339
# Sample:                             0   HQIC                          3416.458
#                                 - 134
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.958e+06   2.25e-11   3.09e+17      0.000    6.96e+06    6.96e+06
# ar.L1          0.9992      0.004    233.654      0.000       0.991       1.008
# ma.L1          0.8351      0.058     14.325      0.000       0.721       0.949
# sigma2      7.463e+09   1.03e-12   7.26e+21      0.000    7.46e+09    7.46e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   8.73   Jarque-Bera (JB):                 1.52
# Prob(Q):                              0.00   Prob(JB):                         0.47
# Heteroskedasticity (H):               4.16   Skew:                             0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.92e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -422.927
# Date:                Sat, 23 Mar 2024   AIC                            853.854
# Time:                        10:08:29   BIC                            859.717
# Sample:                             0   HQIC                           855.798
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.143e+06   9.16e+05      4.524      0.000    2.35e+06    5.94e+06
# ar.L1          0.9694      0.087     11.084      0.000       0.798       1.141
# ma.L1          0.9993      0.162      6.155      0.000       0.681       1.318
# sigma2      1.279e+10      0.224   5.71e+10      0.000    1.28e+10    1.28e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.96   Jarque-Bera (JB):                38.14
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.38   Skew:                            -1.64
# Prob(H) (two-sided):                  0.12   Kurtosis:                         7.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.21e+29. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -778.680
# Date:                Sat, 23 Mar 2024   AIC                           1565.360
# Time:                        10:08:29   BIC                           1573.737
# Sample:                             0   HQIC                          1568.637
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.598e+06   4.62e-09   9.95e+14      0.000     4.6e+06     4.6e+06
# ar.L1          0.9813      0.043     23.037      0.000       0.898       1.065
# ma.L1          0.9936      0.103      9.615      0.000       0.791       1.196
# sigma2       1.05e+10   9.87e-12   1.06e+21      0.000    1.05e+10    1.05e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  18.66   Jarque-Bera (JB):               158.60
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.31   Skew:                            -1.92
# Prob(H) (two-sided):                  0.01   Kurtosis:                         9.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.38e+36. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   88
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1129.101
# Date:                Sat, 23 Mar 2024   AIC                           2266.203
# Time:                        10:08:30   BIC                           2276.112
# Sample:                             0   HQIC                          2270.195
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.117e+06   1.38e-09   3.71e+15      0.000    5.12e+06    5.12e+06
# ar.L1          0.9878      0.018     53.654      0.000       0.952       1.024
# ma.L1          0.9897      0.074     13.423      0.000       0.845       1.134
# sigma2      8.235e+09   8.43e-12   9.77e+20      0.000    8.23e+09    8.23e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  23.60   Jarque-Bera (JB):               367.37
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.21   Skew:                            -2.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.33e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  116
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1477.660
# Date:                Sat, 23 Mar 2024   AIC                           2963.319
# Time:                        10:08:30   BIC                           2974.334
# Sample:                             0   HQIC                          2967.790
#                                 - 116
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        5.61e+06   1.95e-10   2.87e+16      0.000    5.61e+06    5.61e+06
# ar.L1          0.9948      0.009    112.886      0.000       0.978       1.012
# ma.L1          0.9549      0.043     22.189      0.000       0.871       1.039
# sigma2      7.002e+09   2.89e-12   2.42e+21      0.000       7e+09       7e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.26   Jarque-Bera (JB):               714.19
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.25   Skew:                            -2.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.67e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1844.553
# Date:                Sat, 23 Mar 2024   AIC                           3697.105
# Time:                        10:08:31   BIC                           3708.985
# Sample:                             0   HQIC                          3701.932
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.339e+06   6.66e-11   9.52e+16      0.000    6.34e+06    6.34e+06
# ar.L1          0.9973      0.005    192.491      0.000       0.987       1.007
# ma.L1          0.9094      0.040     22.790      0.000       0.831       0.988
# sigma2      8.757e+09   1.06e-12    8.3e+21      0.000    8.76e+09    8.76e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  32.50   Jarque-Bera (JB):               434.07
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                            -1.54
# Prob(H) (two-sided):                  0.09   Kurtosis:                        10.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.19e+36. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   45
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -515.437
# Date:                Sat, 23 Mar 2024   AIC                           1038.874
# Time:                        10:08:31   BIC                           1046.101
# Sample:                             0   HQIC                          1041.568
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.856e+06   4.73e-08   8.15e+13      0.000    3.86e+06    3.86e+06
# ar.L1          0.9969      0.007    141.257      0.000       0.983       1.011
# ma.L1          0.9969      0.305      3.272      0.001       0.400       1.594
# sigma2      4.153e+08   7.28e-10   5.71e+17      0.000    4.15e+08    4.15e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  43.24   Jarque-Bera (JB):                 4.00
# Prob(Q):                              0.00   Prob(JB):                         0.14
# Heteroskedasticity (H):               4.09   Skew:                            -0.21
# Prob(H) (two-sided):                  0.01   Kurtosis:                         1.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.31e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   89
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1014.665
# Date:                Sat, 23 Mar 2024   AIC                           2037.329
# Time:                        10:08:32   BIC                           2047.284
# Sample:                             0   HQIC                          2041.342
#                                  - 89
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.616e+06   2.45e-11   1.48e+17      0.000    3.62e+06    3.62e+06
# ar.L1          1.0000   1.67e-05   5.99e+04      0.000       1.000       1.000
# ma.L1          0.9994      0.227      4.398      0.000       0.554       1.445
# sigma2      3.985e+08   5.68e-10   7.01e+17      0.000    3.99e+08    3.99e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  84.76   Jarque-Bera (JB):                 6.75
# Prob(Q):                              0.00   Prob(JB):                         0.03
# Heteroskedasticity (H):               2.66   Skew:                            -0.55
# Prob(H) (two-sided):                  0.01   Kurtosis:                         2.23
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.81e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  133
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1582.250
# Date:                Sat, 23 Mar 2024   AIC                           3172.499
# Time:                        10:08:33   BIC                           3184.061
# Sample:                             0   HQIC                          3177.197
#                                 - 133
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.849e+06   2.84e-09   1.35e+15      0.000    3.85e+06    3.85e+06
# ar.L1          0.9929      0.008    123.921      0.000       0.977       1.009
# ma.L1          0.9985      0.096     10.450      0.000       0.811       1.186
# sigma2      1.167e+09   8.02e-11   1.45e+19      0.000    1.17e+09    1.17e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                 120.84   Jarque-Bera (JB):                 8.67
# Prob(Q):                              0.00   Prob(JB):                         0.01
# Heteroskedasticity (H):               6.50   Skew:                             0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.56e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  177
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -2159.218
# Date:                Sat, 23 Mar 2024   AIC                           4326.435
# Time:                        10:08:34   BIC                           4339.140
# Sample:                             0   HQIC                          4331.588
#                                 - 177
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4
+08
# ===================================================================================
# Ljung-Box (L1) (Q):                 157.43   Jarque-Bera (JB):                 1.40
# Prob(Q):                              0.00   Prob(JB):                         0.50
# Heteroskedasticity (H):               0.33   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.65e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -2472.074
# Date:                Sat, 23 Mar 2024   AIC                           4952.149
# ...
# [2] Covariance matrix is singular or near-singular, with condition number 4.5e+31. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  133
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1384.470
# Date:                Sat, 23 Mar 2024   AIC                           2776.941
# Time:                        10:09:25   BIC                           2788.502
# Sample:                             0   HQIC                          2781.639
#                                 - 133
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.185e+06   1.92e-12   6.16e+17      0.000    1.19e+06    1.19e+06
# ar.L1          1.0000   7.23e-07   1.38e+06      0.000       1.000       1.000
# ma.L1          0.9979      0.179      5.590      0.000       0.648       1.348
# sigma2      5.582e+07   1.02e-09   5.45e+16      0.000    5.58e+07    5.58e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  88.04   Jarque-Bera (JB):                 1.33
# Prob(Q):                              0.00   Prob(JB):                         0.51
# Heteroskedasticity (H):               4.04   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.1e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  177
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1840.827
# Date:                Sat, 23 Mar 2024   AIC                           3689.655
# Time:                        10:09:26   BIC                           3702.359
# Sample:                             0   HQIC                          3694.807
#                                 - 177
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.448e+06   5.58e-11   2.59e+16      0.000    1.45e+06    1.45e+06
# ar.L1          0.9999      0.001   1228.610      0.000       0.998       1.001
# ma.L1          0.9838      0.026     38.444      0.000       0.934       1.034
# sigma2      5.877e+07   3.58e-11   1.64e+18      0.000    5.88e+07    5.88e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                 110.82   Jarque-Bera (JB):               214.37
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.09   Skew:                            -1.70
# Prob(H) (two-sided):                  0.01   Kurtosis:                         7.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.02e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -2327.248
# Date:                Sat, 23 Mar 2024   AIC                           4662.496
# Time:                        10:09:27   BIC                           4676.089
# Sample:                             0   HQIC                          4667.985
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.594e+06   7.08e-11   2.25e+16      0.000    1.59e+06    1.59e+06
# ar.L1          0.9999      0.001   1411.872      0.000       0.998       1.001
# ma.L1          0.9405      0.021     44.100      0.000       0.899       0.982
# sigma2      7.786e+07    4.6e-11   1.69e+18      0.000    7.79e+07    7.79e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  93.62   Jarque-Bera (JB):                84.05
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.42   Skew:                            -0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.90
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.46e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   45
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -430.782
# Date:                Sat, 23 Mar 2024   AIC                            869.564
# Time:                        10:09:27   BIC                            876.791
# Sample:                             0   HQIC                           872.258
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.591e+05   2.07e-07   4.16e+12      0.000    8.59e+05    8.59e+05
# ar.L1          0.9988      0.007    147.857      0.000       0.986       1.012
# ma.L1          0.9999      0.418      2.394      0.017       0.181       1.819
# sigma2      9.432e+06   4.45e-08   2.12e+14      0.000    9.43e+06    9.43e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.45   Jarque-Bera (JB):                11.73
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.63   Skew:                            -0.87
# Prob(H) (two-sided):                  0.02   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.74e+29. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   89
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -895.731
# Date:                Sat, 23 Mar 2024   AIC                           1799.463
# Time:                        10:09:28   BIC                           1809.417
# Sample:                             0   HQIC                          1803.475
#                                  - 89
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.056e+06   1.73e-08   6.09e+13      0.000    1.06e+06    1.06e+06
# ar.L1          0.9997      0.001    767.699      0.000       0.997       1.002
# ma.L1          1.0000      0.224      4.468      0.000       0.561       1.439
# sigma2      2.795e+07   8.01e-09   3.49e+15      0.000    2.79e+07    2.79e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  53.56   Jarque-Bera (JB):                 1.80
# Prob(Q):                              0.00   Prob(JB):                         0.41
# Heteroskedasticity (H):               7.33   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.59e+31. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  133
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1369.595
# Date:                Sat, 23 Mar 2024   AIC                           2747.190
# Time:                        10:09:28   BIC                           2758.751
# Sample:                             0   HQIC                          2751.888
#                                 - 133
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.367e+06   2.26e-12   6.06e+17      0.000    1.37e+06    1.37e+06
# ar.L1          1.0000   6.69e-07    1.5e+06      0.000       1.000       1.000
# ma.L1          0.9976      0.128      7.791      0.000       0.747       1.249
# sigma2      4.467e+07   1.73e-09   2.58e+16      0.000    4.47e+07    4.47e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                 111.71   Jarque-Bera (JB):                 2.52
# Prob(Q):                              0.00   Prob(JB):                         0.28
# Heteroskedasticity (H):               9.02   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.25e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  177
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -1835.037
# Date:                Sat, 23 Mar 2024   AIC                           3678.075
# Time:                        10:09:28   BIC                           3690.779
# Sample:                             0   HQIC                          3683.227
#                                 - 177
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.478e+06   1.92e-13   7.72e+18      0.000    1.48e+06    1.48e+06
# ar.L1          1.0000   3.77e-07   2.65e+06      0.000       1.000       1.000
# ma.L1          0.9980      0.092     10.827      0.000       0.817       1.179
# sigma2      5.283e+07   1.05e-09   5.02e+16      0.000    5.28e+07    5.28e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                 124.20   Jarque-Bera (JB):                35.66
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.23   Skew:                            -0.96
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.55e+41. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(1, 0, 1)   Log Likelihood               -2331.556
# Date:                Sat, 23 Mar 2024   AIC                           4671.112
# Time:                        10:09:29   BIC                           4684.705
# Sample:                             0   HQIC                          4676.601
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.574e+06        nan        nan        nan         nan         nan
# ar.L1          1.0000    1.7e-07    5.9e+06      0.000       1.000       1.000
# ma.L1          0.9757      0.012     84.028      0.000       0.953       0.998
# sigma2      7.851e+07   2.04e-13   3.85e+20      0.000    7.85e+07    7.85e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                 145.28   Jarque-Bera (JB):                14.92
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               6.18   Skew:                            -0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.71e+40. Standard errors may be unstable.

# %%
print(results_df.head())
print(results_df.shape)
# Out:
#    County      Forecast        Real  Percentage Change
# 0   10021  9.830246e+06  10883800.0          -9.680016
# 1   10021  1.077231e+07  13043800.0         -17.414338
# 2   10021  1.275458e+07  11630200.0           9.667799
# 3   10021  1.158979e+07  18341500.0         -36.811086
# 4   10021  1.814076e+07  17894900.0           1.373918
# (150, 4)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
forecast = results_df['Forecast']
actual = results_df['Real']


mape = np.mean(np.abs((actual - forecast) / actual)) * 100
smape = np.mean(2 * np.abs(forecast - actual) / (np.abs(actual) + np.abs(forecast))) * 100

# %%
print("Mean absolute percentage error :", mape)
print("Symmetric Mean absolute percentage error :", smape)
# Out:
# Mean absolute percentage error : 22.4507724511962
# Symmetric Mean absolute percentage error : 25.333960637305914

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> Auto arima model</span></b> </div>

# %% [markdown]
# After doing forecasting on the selected zipcodes using a baseline model, we go ahead and try to use the auto arima to get the best pdq combinations to minimze the AIC score.
#
# The idea of looping and using the **TrainTestSplit** comes in handy as various combinations are tried for every fold to get the lowest AIC scores.

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /usr/local/lib/python3.10/dist-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.9)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.25.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.11.4)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.0.7)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (67.7.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.3.0)
# Requirement already satisfied: patsy>=0.5.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.4->statsmodels>=0.13.2->pmdarima) (1.16.0)

# %%
# Use the auto arima model to get the best pdq values.
from pmdarima import auto_arima
for county in high_value_zipcodes:
    county_data = df_melted[df_melted['RegionName'] == county]

    # Split the data
    dates = county_data.index
    values = county_data['value'].values

    # accumulate results for each fold
    zip_train_dates, zip_test_dates = [], []
    zip_train_values, zip_test_values = [], []

    for train_index, test_index in tsc.split(dates):
        train_dates, test_dates = dates[train_index], dates[test_index]
        train_values, test_values = values[train_index], values[test_index]

        zip_train_dates.extend(train_dates)
        zip_test_dates.extend(test_dates)
        zip_train_values.extend(train_values)
        zip_test_values.extend(test_values)


        auto_model = auto_arima(train_values, trace=True, suppress_warnings=True)
        auto_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=798.472, Time=0.39 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=991.727, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=983.334, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1124.743, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=858.266, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.17 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=783.861, Time=0.15 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=833.611, Time=0.15 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=770.890, Time=0.22 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=823.210, Time=0.10 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=779.520, Time=0.41 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=848.143, Time=0.47 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=777.923, Time=0.40 sec
#
# Best model:  ARIMA(2,0,4)(0,0,0)[0] intercept
# Total fit time: 4.701 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=1450.792, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1838.798, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1738.403, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1774.416, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=2105.499, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.80 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=1411.444, Time=0.44 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=1522.909, Time=0.20 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=1397.653, Time=0.95 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=1489.499, Time=0.58 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=1393.815, Time=1.02 sec
#  ARIMA(1,0,5)(0,0,0)[0] intercept   : AIC=1450.173, Time=0.44 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=inf, Time=1.41 sec
#
# Best model:  ARIMA(2,0,5)(0,0,0)[0] intercept
# Total fit time: 13.117 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.96 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2207.568, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=2219.421, Time=0.05 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=inf, Time=0.15 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=2239.952, Time=0.09 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2208.921, Time=0.03 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 1.349 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.40 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3180.004, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3755.574, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3219.300, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3178.797, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3720.774, Time=1.26 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 3.559 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=3769.890, Time=0.35 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=3731.986, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=3734.291, Time=0.07 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=3737.116, Time=0.57 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=3739.385, Time=1.63 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=3733.609, Time=0.04 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 2.711 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.60 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=738.127, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=791.524, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=737.581, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=743.654, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=871.165, Time=0.38 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=737.818, Time=0.07 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=871.607, Time=0.34 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=740.597, Time=0.04 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 2.668 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2813.419, Time=1.27 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1383.358, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1524.894, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1382.398, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1408.317, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1827.256, Time=0.36 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=1389.359, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2471.041, Time=0.52 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=1404.055, Time=0.05 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 2.646 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.53 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2059.979, Time=0.04 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2100.397, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2075.072, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2075.191, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2144.091, Time=0.33 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 2.233 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2772.621, Time=0.92 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2750.938, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2788.558, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2759.844, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2772.214, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2793.740, Time=0.36 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0] intercept
# Total fit time: 1.550 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3494.074, Time=0.97 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=
sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0] intercept
# Total fit time: 4.075 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.44 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5116.764, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5377.540, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5092.376, Time=0.07 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5139.984, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5553.627, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5095.333, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5738.138, Time=0.20 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5106.507, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 2.137 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=650.074, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=651.840, Time=0.06 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=653.476, Time=0.02 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=636.773, Time=0.15 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=637.987, Time=0.15 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=637.984, Time=0.16 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=653.727, Time=0.08 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=657.024, Time=0.03 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=644.310, Time=0.14 sec
#
# Best model:  ARIMA(1,2,1)(0,0,0)[0]
# Total fit time: 1.052 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1333.341, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1335.291, Time=0.06 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1335.291, Time=0.06 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1322.754, Time=0.29 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=inf, Time=0.12 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=inf, Time=0.28 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=1337.254, Time=0.17 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=1347.507, Time=0.04 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1335.053, Time=0.17 sec
#
# Best model:  ARIMA(1,2,1)(0,0,0)[0]
# Total fit time: 1.586 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=2220.712, Time=0.42 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2209.479, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=2211.367, Time=0.08 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=2211.367, Time=0.10 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=2210.859, Time=0.41 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2211.335, Time=0.04 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 1.080 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=3409.636, Time=0.31 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=3369.489, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=3373.879, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=3388.573, Time=0.03 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=3396.620, Time=0.12 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=3371.260, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.549 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=4466.735, Time=0.48 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=4428.835, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=4430.697, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=4436.572, Time=0.07 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=inf, Time=0.16 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=4430.813, Time=0.02 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.799 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=687.475, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=671.293, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=673.284, Time=0.06 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=674.632, Time=0.09 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=668.284, Time=0.18 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=671.582, Time=0.18 sec
#  ARIMA(1,2,2)(0,0,0)[0]             : AIC=671.941, Time=0.19 sec
#  ARIMA(0,2,2)(0,0,0)[0]             : AIC=681.227, Time=0.04 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=682.993, Time=0.05 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=674.491, Time=0.18 sec
#
# Best model:  ARIMA(1,2,1)(0,0,0)[0]
# Total fit time: 1.030 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1430.716, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=1457.893, Time=0.02 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=1432.675, Time=0.06 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=1472.756, Time=0.53 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1425.475, Time=0.02 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1427.230, Time=0.16 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1427.684, Time=0.13 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1460.628, Time=0.21 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0] intercept
# Total fit time: 1.507 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=2408.126, Time=0.28 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2261.596, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=2344.607, Time=0.04 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=2283.937, Time=0.04 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=inf, Time=0.24 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2263.383, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.633 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0]             : AIC=3241.598, Time=0.28 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=3216.875, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0]             : AIC=3233.077, Time=0.03 sec
#  ARIMA(0,2,1)(0,0,0)[0]             : AIC=3227.126, Time=0.06 sec
#  ARIMA(1,2,1)(0,0,0)[0]             : AIC=3235.048, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=3218.816, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.445 seconds
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.84 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=4855.353, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=4874.552, Time=0.28 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=4845.213, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=4906.714, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=4820.309, Time=1.07 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=4816.614, Time=0.82 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=4863.511, Time=0.50 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=4816.953, Time=0.77 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=4817.051, Time=0.63 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=4856.163, Time=0.70 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=9019.997, Time=0.90 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=inf, Time=0.51 sec
#
# Best model:  ARIMA(2,1,1)(0,0,0)[0] intercept
# Total fit time: 8.227 seconds

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> ARIMA(Best model)</span></b>

# %% [markdown]
# From the previous iteration we'll choose the best model parameters and apply them on the next model

# %%
def model_func(order):
    """
    Function to take in various pdq values and do forecasting on the selected values.
    """

    results_list2 = []
    for county in high_value_zipcodes:
        county_data = df_melted[df_melted['RegionName'] == county]

        # Split the data
        dates = county_data.index
        values = county_data['value'].values

        # accumulate values for each fold
        zip_train_dates, zip_test_dates = [], []
        zip_train_values, zip_test_values = [], []

        for train_index, test_index in tsc.split(dates):
            train_dates, test_dates = dates[train_index], dates[test_index]
            train_values, test_values = values[train_index], values[test_index]

            zip_train_dates.extend(train_dates)
            zip_test_dates.extend(test_dates)
            zip_train_values.extend(train_values)
            zip_test_values.extend(test_values)


            model = ARIMA(train_values, order=order).fit()
            forecast = pd.Series(model.predict(start=len(train_values), end=len(train_values) + 11, typ='levels'))

            print(model.summary())

            all_forecasts.extend(forecast)


            forecasted_value = forecast.iloc[-1]
            real_value = test_values[-1]
            percentage_change = ((forecasted_value - real_value) / real_value) * 100

            results_df = pd.DataFrame(results_list2.append({'County': county, 'Forecast': forecasted_value, 'Real': real_value, 'Percentage Change': percentage_change}))

    return results_df

# %%
#Apply function with the pdq values of (0,2,0)
model_func(order=(0,2,0))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -387.275
# Date:                Sat, 23 Mar 2024   AIC                            776.550
# Time:                        11:05:12   BIC                            777.951
# Sample:                             0   HQIC                           776.998
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       8.94e+09   1.86e+09      4.802      0.000    5.29e+09    1.26e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  23.71   Jarque-Bera (JB):                 1.48
# Prob(Q):                              0.00   Prob(JB):                         0.48
# Heteroskedasticity (H):               0.44   Skew:                             0.50
# Prob(H) (two-sided):                  0.22   Kurtosis:                         3.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -740.097
# Date:                Sat, 23 Mar 2024   AIC                           1482.194
# Time:                        11:05:12   BIC                           1484.255
# Sample:                             0   HQIC                          1482.997
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      6.855e+09      1e+09      6.843      0.000    4.89e+09    8.82e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  42.83   Jarque-Bera (JB):                 3.65
# Prob(Q):                              0.00   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.31   Skew:                             0.49
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   88
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1102.784
# Date:                Sat, 23 Mar 2024   AIC                           2207.568
# Time:                        11:05:12   BIC                           2210.022
# Sample:                             0   HQIC                          2208.556
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       7.86e+09    8.3e+08      9.469      0.000    6.23e+09    9.49e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  32.57   Jarque-Bera (JB):                20.19
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             0.81
# Prob(H) (two-sided):                  0.81   Kurtosis:                         4.74
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  116
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1460.437
# Date:                Sat, 23 Mar 2024   AIC                           2922.875
# Time:                        11:05:12   BIC                           2925.611
# Sample:                             0   HQIC                          2923.985
#                                 - 116
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      7.714e+09   6.99e+08     11.039      0.000    6.34e+09    9.08e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  31.64   Jarque-Bera (JB):                22.16
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.76   Skew:                             0.37
# Prob(H) (two-sided):                  0.41   Kurtosis:                         5.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1864.993
# Date:                Sat, 23 Mar 2024   AIC                           3731.986
# Time:                        11:05:12   BIC                           3734.942
# Sample:                             0   HQIC                          3733.187
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.477e+10   1.08e+09     13.705      0.000    1.27e+10    1.69e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.71   Jarque-Bera (JB):                62.76
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.23   Skew:                            -0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   30
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -336.808
# Date:                Sat, 23 Mar 2024   AIC                            675.615
# Time:                        11:05:12   BIC                            676.947
# Sample:                             0   HQIC                           676.022
#                                  - 30
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       1.53e+09   5.47e+08      2.795      0.005    4.57e+08     2.6e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  20.41   Jarque-Bera (JB):                 1.27
# Prob(Q):                              0.00   Prob(JB):                         0.53
# Heteroskedasticity (H):               1.18   Skew:                             0.18
# Prob(H) (two-sided):                  0.81   Kurtosis:                         2.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   56
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -643.992
# Date:                Sat, 23 Mar 2024   AIC                           1289.985
# Time:                        11:05:12   BIC                           1291.974
# Sample:                             0   HQIC                          1290.752
#                                  - 56
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.288e+09   3.03e+08      4.251      0.000    6.94e+08    1.88e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.07   Jarque-Bera (JB):                 1.65
# Prob(Q):                              0.00   Prob(JB):                         0.44
# Heteroskedasticity (H):               0.65   Skew:                             0.26
# Prob(H) (two-sided):                  0.38   Kurtosis:                         2.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   82
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -987.853
# Date:                Sat, 23 Mar 2024   AIC                           1977.706
# Time:                        11:05:12   BIC                           1980.088
# Sample:                             0   HQIC                          1978.661
#                                  - 82
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.035e+09   3.75e+08      8.089      0.000     2.3e+09    3.77e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.76   Jarque-Bera (JB):                 4.73
# Prob(Q):                              0.00   Prob(JB):                         0.09
# Heteroskedasticity (H):               3.89   Skew:                            -0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  108
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1330.474
# Date:                Sat, 23 Mar 2024   AIC                           2662.948
# Time:                        11:05:12   BIC                           2665.611
# Sample:                             0   HQIC                          2664.027
#                                 - 108
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      4.587e+09   5.82e+08      7.887      0.000    3.45e+09    5.73e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.65   Jarque-Bera (JB):                 1.22
# Prob(Q):                              0.06   Prob(JB):                         0.54
# Heteroskedasticity (H):               6.25   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  134
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1671.990
# Date:                Sat, 23 Mar 2024   AIC                           3345.979
# Time:                        11:05:13   BIC                           3348.862
# Sample:                             0   HQIC                          3347.151
#                                 - 134
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      5.794e+09   6.66e+08      8.697      0.000    4.49e+09     7.1e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.39   Jarque-Bera (JB):                 0.83
# Prob(Q):                              0.04   Prob(JB):                         0.66
# Heteroskedasticity (H):               6.78   Skew:                            -0.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -379.975
# Date:                Sat, 23 Mar 2024   AIC                            761.951
# Time:                        11:05:13   BIC                            763.352
# Sample:                             0   HQIC                           762.399
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      5.495e+09   1.55e+09      3.540      0.000    2.45e+09    8.54e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  22.48   Jarque-Bera (JB):                 0.56
# Prob(Q):                              0.00   Prob(JB):                         0.76
# Heteroskedasticity (H):               0.87   Skew:                            -0.28
# Prob(H) (two-sided):                  0.83   Kurtosis:                         2.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -726.243
# Date:                Sat, 23 Mar 2024   AIC                           1454.487
# Time:                        11:05:13   BIC                           1456.547
# Sample:                             0   HQIC                          1455.290
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      4.251e+09   8.17e+08      5.201      0.000    2.65e+09    5.85e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  39.00   Jarque-Bera (JB):                 0.24
# Prob(Q):                              0.00   Prob(JB):                         0.89
# Heteroskedasticity (H):               0.52   Skew:                            -0.13
# Prob(H) (two-sided):                  0.17   Kurtosis:                         2.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   88
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1076.299
# Date:                Sat, 23 Mar 2024   AIC                           2154.598
# Time:                        11:05:13   BIC                           2157.053
# Sample:                             0   HQIC                          2155.586
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      4.245e+09   7.06e+08      6.015      0.000    2.86e+09    5.63e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  27.55   Jarque-Bera (JB):                 0.57
# Prob(Q):                              0.00   Prob(JB):                         0.75
# Heteroskedasticity (H):               0.71   Skew:                            -0.01
# Prob(H) (two-sided):                  0.36   Kurtosis:                         2.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  116
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1420.519
# Date:                Sat, 23 Mar 2024   AIC                           2843.038
# Time:                        11:05:13   BIC                           2845.774
# Sample:                             0   HQIC                          2844.149
#                                 - 116
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.829e+09   5.11e+08      7.491      0.000    2.83e+09    4.83e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  27.50   Jarque-Bera (JB):                 0.13
# Prob(Q):                              0.00   Prob(JB):                         0.94
# Heteroskedasticity (H):               0.62   Skew:                             0.06
# Prob(H) (two-sided):                  0.15   Kurtosis:                         2.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1793.011
# Date:                Sat, 23 Mar 2024   AIC                           3588.022
# Time:                        11:05:13   BIC                           3590.978
# Sample:                             0   HQIC                          3589.223
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      5.357e+09   5.27e+08     10.165      0.000    4.32e+09    6.39e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  15.59   Jarque-Bera (JB):                 8.33
# Prob(Q):                              0.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               1.61   Skew:                             0.48
# Prob(H) (two-sided):                  0.10   Kurtosis:                         3.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   45
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -427.249
# Date:                Sat, 23 Mar 2024   AIC                            856.498
# Time:                        11:05:13   BIC                            858.260
# Sample:                             0   HQIC                           857.148
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      2.386e+07   7.37e+06      3.237      0.001    9.41e+06    3.83e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.36   Jarque-Bera (JB):                 2.49
# Prob(Q):                              0.00   Prob(JB):                         0.29
# Heteroskedasticity (H):               2.34   Skew:                             0.47
# Prob(H) (two-sided):                  0.12   Kurtosis:                         2.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   89
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -882.985
# Date:                Sat, 23 Mar 2024   AIC                           1767.970
# Time:                        11:05:13   BIC                           1770.435
# Sample:                             0   HQIC                          1768.962
#                                  - 89
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.742e+07   4.06e+06      9.206      0.000    2.95e+07    4.54e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  39.51   Jarque-Bera (JB):                13.28
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.81   Skew:                            -0.35
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  133
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -1468.647
# Date:                Sat, 23 Mar 2024   AIC                           2939.293
# Time:                        11:05:13   BIC                           2942.169
# Sample:                             0   HQIC                          2940.462
#                                 - 133
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.153e+08   2.63e+07     11.978      0.000    2.64e+08    3.67e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  94.81   Jarque-Bera (JB):                27.85
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              35.69   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  177
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -2122.414
# Date:                Sat, 23 Mar 2024   AIC                           4246.828
# Time:                        11:05:13   BIC                           4249.992
# Sample:                             0   HQIC                          4248.111
#                                 - 177
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.981e+09   6.57e+07     30.172      0.000    1.85e+09    2.11e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   7.47   Jarque-Bera (JB):              2480.62
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):             206.21   Skew:                            -0.63
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -2720.802
# Date:                Sat, 23 Mar 2024   AIC                           5443.605
# Time:                        11:05:13   BIC                           5446.994
# Sample:                             0   HQIC                          5444.973
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.587e+09   1.56e+08     23.042      0.000    3.28e+09    3.89e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  15.19   Jarque-Bera (JB):               518.85
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             374.75   Skew:                            -0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   45
# Model:                 ARIMA(0, 2, 0)   Log Likelihood                -385.096
# Date:                Sat, 23 Mar 2024   AIC                            772.193
# Time:                        11:05:13   BIC                            773.954
# Sample:                             0   HQIC                           772.842
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -2078.560
# Date:                Sat, 23 Mar 2024   AIC                           4159.121
# Time:                        11:05:16   BIC                           4162.510
# Sample:                             0   HQIC                          4160.490
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.017e+07   6.64e+05     15.331      0.000    8.87e+06    1.15e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  64.91   Jarque-Bera (JB):                45.14
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              57.36   Skew:                             0.15
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.20
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# This model generates an AIC score of 776 which is pretty much lower than the baseline's model score of 891.

# %%
# Analyze the forecasted house values to get their respective growth rates.
avg_results2 = results_df.groupby('County')[['Forecast', 'Real']].mean().reset_index()
avg_results2['Diff'] =avg_results['Real'] - avg_results2['Forecast']
top_5 = avg_results2.sort_values(by='Diff', ascending=False).head(5)
sns.barplot(data=top_5, x='County', y='Diff')
plt.title("Top 5 zipcodes with high growth rates")
plt.show()

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> ARIMA(1,2,1)</span></b> </div>

# %% [markdown]
# We set out to try another combination of pdq values to analyze the **AIC scores** as compaired to the other **ARIMA** model.

# %%
#Apply function using the order (1,2,1).
model_func(order=(1,2,1))
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -385.705
# Date:                Sat, 23 Mar 2024   AIC                            777.410
# Time:                        11:05:44   BIC                            781.613
# Sample:                             0   HQIC                           778.754
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9276      0.025     36.982      0.000       0.878       0.977
# ma.L1         -1.0000      0.267     -3.748      0.000      -1.523      -0.477
# sigma2      8.403e+09   3.17e-11   2.65e+20      0.000     8.4e+09     8.4e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  22.26   Jarque-Bera (JB):                 0.46
# Prob(Q):                              0.00   Prob(JB):                         0.80
# Heteroskedasticity (H):               0.70   Skew:                             0.29
# Prob(H) (two-sided):                  0.58   Kurtosis:                         3.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.13e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -827.438
# Date:                Sat, 23 Mar 2024   AIC                           1660.877
# Time:                        11:05:44   BIC                           1667.058
# Sample:                             0   HQIC                          1663.284
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3900      0.373      1.046      0.296      -0.341       1.121
# ma.L1         -0.3832      0.370     -1.036      0.300      -1.108       0.342
# sigma2      1.213e+09   1.48e-09    8.2e+17      0.000    1.21e+09    1.21e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  42.68   Jarque-Bera (JB):                 3.27
# Prob(Q):                              0.00   Prob(JB):                         0.19
# Heteroskedasticity (H):               0.31   Skew:                             0.44
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.06e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   88
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1116.976
# Date:                Sat, 23 Mar 2024   AIC                           2239.952
# Time:                        11:05:44   BIC                           2247.315
# Sample:                             0   HQIC                          2242.915
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6771      2.054     -0.330      0.742      -4.703       3.349
# ma.L1          0.6775      2.049      0.331      0.741      -3.338       4.693
# sigma2      3.928e+09   5.28e-09   7.44e+17      0.000    3.93e+09    3.93e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  32.49   Jarque-Bera (JB):                20.11
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.10   Skew:                             0.81
# Prob(H) (two-sided):                  0.81   Kurtosis:                         4.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.22e+32. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  116
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1468.014
# Date:                Sat, 23 Mar 2024   AIC                           2942.028
# Time:                        11:05:45   BIC                           2950.236
# Sample:                             0   HQIC                          2945.359
#                                 - 116
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3522      1.569      0.224      0.822      -2.724       3.428
# ma.L1         -0.3451      1.556     -0.222      0.824      -3.394       2.704
# sigma2      4.804e+09      2e-09   2.41e+18      0.000     4.8e+09     4.8e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  30.96   Jarque-Bera (JB):                22.12
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.77   Skew:                             0.34
# Prob(H) (two-sided):                  0.42   Kurtosis:                         5.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.66e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1866.693
# Date:                Sat, 23 Mar 2024   AIC                           3739.385
# Time:                        11:05:46   BIC                           3748.252
# Sample:                             0   HQIC                          3742.988
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1777      3.669      0.048      0.961      -7.013       7.368
# ma.L1         -0.1722      3.652     -0.047      0.962      -7.330       6.986
# sigma2      1.198e+10   2.05e-08   5.85e+17      0.000     1.2e+10     1.2e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  13.39   Jarque-Bera (JB):                64.03
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.26   Skew:                            -0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.49e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   30
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -349.707
# Date:                Sat, 23 Mar 2024   AIC                            705.413
# Time:                        11:05:46   BIC                            709.410
# Sample:                             0   HQIC                           706.635
#                                  - 30
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6480      0.089      7.260      0.000       0.473       0.823
# ma.L1         -0.5978      0.081     -7.377      0.000      -0.757      -0.439
# sigma2      4.141e+08   2.31e-12   1.79e+20      0.000    4.14e+08    4.14e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  17.97   Jarque-Bera (JB):                 1.07
# Prob(Q):                              0.00   Prob(JB):                         0.59
# Heteroskedasticity (H):               1.81   Skew:                             0.04
# Prob(H) (two-sided):                  0.39   Kurtosis:                         2.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.23e+37. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   56
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -656.116
# Date:                Sat, 23 Mar 2024   AIC                           1318.232
# Time:                        11:05:47   BIC                           1324.199
# Sample:                             0   HQIC                          1320.533
#                                  - 56
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000      0.592      1.688      0.091      -0.161       2.161
# ma.L1         -1.0000      1.018     -0.982      0.326      -2.996       0.996
# sigma2      4.116e+09   8.85e-10   4.65e+18      0.000    4.12e+09    4.12e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.07   Jarque-Bera (JB):                 1.65
# Prob(Q):                              0.00   Prob(JB):                         0.44
# Heteroskedasticity (H):               0.65   Skew:                             0.26
# Prob(H) (two-sided):                  0.38   Kurtosis:                         2.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.66e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   82
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -990.215
# Date:                Sat, 23 Mar 2024   AIC                           1986.430
# Time:                        11:05:47   BIC                           1993.576
# Sample:                             0   HQIC                          1989.295
#                                  - 82
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8186      1.174     -0.697      0.486      -3.120       1.483
# ma.L1          0.8202      1.169      0.702      0.483      -1.471       3.111
# sigma2      2.235e+09   9.66e-11   2.31e+19      0.000    2.23e+09    2.23e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.66   Jarque-Bera (JB):                 4.76
# Prob(Q):                              0.00   Prob(JB):                         0.09
# Heteroskedasticity (H):               3.88   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.66e+36. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  108
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1331.240
# Date:                Sat, 23 Mar 2024   AIC                           2668.481
# Time:                        11:05:47   BIC                           2676.471
# Sample:                             0   HQIC                          2671.719
#                                 - 108
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9687      0.319     -3.034      0.002      -1.595      -0.343
# ma.L1          0.9692      0.316      3.063      0.002       0.349       1.589
# sigma2      3.949e+09   1.25e-10   3.17e+19      0.000    3.95e+09    3.95e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.63   Jarque-Bera (JB):                 1.22
# Prob(Q):                              0.06   Prob(JB):                         0.54
# Heteroskedasticity (H):               6.25   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.05e+36. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  134
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1671.735
# Date:                Sat, 23 Mar 2024   AIC                           3349.470
# Time:                        11:05:48   BIC                           3358.118
# Sample:                             0   HQIC                          3352.984
#                                 - 134
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0141      1.321     -0.011      0.991      -2.603       2.575
# ma.L1          0.0321      1.302      0.025      0.980      -2.520       2.585
# sigma2      5.457e+09   9.43e-10   5.79e+18      0.000    5.46e+09    5.46e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.76   Jarque-Bera (JB):                 0.87
# Prob(Q):                              0.05   Prob(JB):                         0.65
# Heteroskedasticity (H):               6.90   Skew:                            -0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.04e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   32
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -450.315
# Date:                Sat, 23 Mar 2024   AIC                            906.629
# Time:                        11:05:48   BIC                            910.833
# Sample:                             0   HQIC                           907.974
#                                  - 32
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7832      0.019     41.842      0.000       0.747       0.820
# ma.L1         -0.9033      0.020    -45.710      0.000      -0.942      -0.865
# sigma2      4.662e+08   3.03e-12   1.54e+20      0.000    4.66e+08    4.66e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  23.43   Jarque-Bera (JB):                 4.05
# Prob(Q):                              0.00   Prob(JB):                         0.13
# Heteroskedasticity (H):              18.06   Skew:                            -0.89
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.39e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   60
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -775.066
# Date:                Sat, 23 Mar 2024   AIC                           1556.133
# Time:                        11:05:48   BIC                           1562.314
# Sample:                             0   HQIC                          1558.541
#                                  - 60
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8311      0.008    101.362      0.000       0.815       0.847
# ma.L1         -1.0000      0.038    -26.613      0.000      -1.074      -0.926
# sigma2      7.056e+08   5.33e-11   1.32e+19      0.000    7.06e+08    7.06e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  40.87   Jarque-Bera (JB):                 3.44
# Prob(Q):                              0.00   Prob(JB):                         0.18
# Heteroskedasticity (H):               1.57   Skew:                            -0.59
# Prob(H) (two-sided):                  0.33   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.69e+33. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   88
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1076.191
# Date:                Sat, 23 Mar 2024   AIC                           2158.382
# Time:                        11:05:48   BIC                           2165.745
# Sample:                             0   HQIC                          2161.345
#                                  - 88
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8254      0.021     40.162      0.000       0.785       0.866
# ma.L1         -1.0000      0.084    -11.854      0.000      -1.165      -0.835
# sigma2      1.801e+09   4.69e-11   3.84e+19      0.000     1.8e+09     1.8e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  26.66   Jarque-Bera (JB):                 1.03
# Prob(Q):                              0.00   Prob(JB):                         0.60
# Heteroskedasticity (H):               1.05   Skew:                            -0.26
# Prob(H) (two-sided):                  0.90   Kurtosis:                         2.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.61e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  116
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1407.987
# Date:                Sat, 23 Mar 2024   AIC                           2821.974
# Time:                        11:05:49   BIC                           2830.182
# Sample:                             0   HQIC                          2825.305
#                                 - 116
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8243      0.034     24.521      0.000       0.758       0.890
# ma.L1         -1.0000      0.132     -7.563      0.000      -1.259      -0.741
# sigma2      3.065e+09   4.31e-11    7.1e+19      0.000    3.06e+09    3.06e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  26.94   Jarque-Bera (JB):                 0.54
# Prob(Q):                              0.00   Prob(JB):                         0.76
# Heteroskedasticity (H):               0.81   Skew:                            -0.13
# Prob(H) (two-sided):                  0.53   Kurtosis:                         3.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.4e+34. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  144
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1781.322
# Date:                Sat, 23 Mar 2024   AIC                           3568.644
# Time:                        11:05:49   BIC                           3577.511
# Sample:                             0   HQIC                          3572.247
#                                 - 144
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8138      0.030     27.338      0.000       0.755       0.872
# ma.L1         -0.9999      0.089    -11.263      0.000      -1.174      -0.826
# sigma2      3.892e+09   2.26e-11   1.72e+20      0.000    3.89e+09    3.89e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  16.04   Jarque-Bera (JB):                 7.15
# Prob(Q):                              0.00   Prob(JB):                         0.03
# Heteroskedasticity (H):               2.01   Skew:                             0.37
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number  2e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   45
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -424.948
# Date:                Sat, 23 Mar 2024   AIC                            855.896
# Time:                        11:05:49   BIC                            861.180
# Sample:                             0   HQIC                           857.845
#                                  - 45
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000      0.011     87.566      0.000       0.978       1.022
# ma.L1         -0.9995      0.337     -2.966      0.003      -1.660      -0.339
# sigma2      2.203e+07   1.71e-08   1.29e+15      0.000     2.2e+07     2.2e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.37   Jarque-Bera (JB):                 2.53
# Prob(Q):                              0.00   Prob(JB):                         0.28
# Heteroskedasticity (H):               2.71   Skew:                             0.50
# Prob(H) (two-sided):                  0.07   Kurtosis:                         2.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.39e+30. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   89
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -919.969
# Date:                Sat, 23 Mar 2024   AIC                           1845.939
# Time:                        11:05:49   BIC                           1853.337
# Sample:                             0   HQIC                          1848.918
#                                  - 89
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9628      0.182     -5.278      0.000      -1.320      -0.605
# ma.L1          0.9628      0.182      5.283      0.000       0.606       1.320
# sigma2      1.309e+07   3.58e-08   3.65e+14      0.000    1.31e+07    1.31e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  39.54   Jarque-Bera (JB):                13.23
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.81   Skew:                            -0.35
# Prob(H) (two-sided):                  0.01   Kurtosis:                         4.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.03e+30. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  133
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -1468.651
# Date:                Sat, 23 Mar 2024   AIC                           2943.302
# Time:                        11:05:49   BIC                           2951.928
# Sample:                             0   HQIC                          2946.807
#                                 - 133
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.0000      0.115      8.673      0.000       0.774       1.226
# ma.L1         -0.9999      0.203     -4.935      0.000      -1.397      -0.603
# sigma2      3.234e+08   1.93e-09   1.67e+17      0.000    3.23e+08    3.23e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                  94.81   Jarque-Bera (JB):                27.82
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              35.70   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 9.01e+31. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  177
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -2124.662
# Date:                Sat, 23 Mar 2024   AIC                           4255.325
# Time:                        11:05:49   BIC                           4264.819
# Sample:                             0   HQIC                          4259.176
#                                 - 177
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8014      5.406     -0.148      0.882     -11.396       9.793
# ma.L1          0.8029      5.397      0.149      0.882      -9.775      11.381
# sigma2      1.604e+09   5.04e-07   3.18e+15      0.000     1.6e+09     1.6e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   7.41   Jarque-Bera (JB):              2471.16
# Prob(Q):                              0.01   Prob(JB):                         0.00
# Heteroskedasticity (H):             180.67   Skew:                            -0.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.86e+30. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -2721.173
# Date:                Sat, 23 Mar 2024   AIC                           5448.347
# Time:                        11:05:50   BIC                           5458.514
# Sample:                             0   HQIC                          5452.453
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1961      1.803     -0.109      0.913      -3.730       3.337
# ma.L1          0.2100      1.784      0.118      0.906      -3.286       3.706
# sigma2      3.167e+09   1.29e-08   2.46e+17      0.000    3.17e+09    3.17e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                  14.49   Jarque-Bera (JB):               502.22
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             128.71   Skew:                            -0.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.04e+32. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   45
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                
01
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  221
# Model:                 ARIMA(1, 2, 1)   Log Likelihood               -2088.864
# Date:                Sat, 23 Mar 2024   AIC                           4183.729
# Time:                        11:06:17   BIC                           4193.896
# Sample:                             0   HQIC                          4187.835
#                                 - 221
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1150      7.456     -0.015      0.988     -14.728      14.498
# ma.L1          0.1177      7.441      0.016      0.987     -14.466      14.702
# sigma2       6.82e+06      0.000   3.48e+10      0.000    6.82e+06    6.82e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  64.39   Jarque-Bera (JB):                44.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              52.07   Skew:                             0.14
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.1e+25. Standard errors may be unstable.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# This model generates a higher AIC than the previous model. We aim to reduce the AIC scores. This model is not the perfect model to get the zipcodes which have a better prospects of growth.

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> FaceBook model</span></b> </div>
#
# After testing out the various ARIMA models, we seek to try out the **FaceBook** prophet model which handles the concept of seasonalty pretty well. The prophet model however requires the data columns to be in **ds** for the date column and **y** for the target column.
#
# To have a simple modelling process, we reset the index for the modelling data to make the time column extraction easy using the loop and later save the results to a CSV file. This data will be processed through an **Extract-Transform-Load** pipeline having the Prophet model.
#
# The concept of automation is very paramount because it helps in easier code manageability and debugging. It also offers better scalability especially when dealing with huge projects.
# this is manageable by using the traditional **OOP** approach where everything is automated from the ingestion of data, renaming of columns, dropping null values, training, evaluating a model and later saving the model for future deployment purposes.

# %%
df_melted.reset_index(inplace=True)

# %%
# Create a csv file for easier prediction of top performing zipcodes.
for county in high_value_zipcodes:
    county_data = df_melted[df_melted['RegionName'] == county][['time', 'value']].copy()
    county_data.to_csv('Zipcode_predict.csv')

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Average House prediction</b>
#
# The data to be used in the forecasting of the average house prices for every month comes from the melt function. The data is aggregated on a monthly basis together with their respective average values.

# %%
# ETL-like class pipeline to apply the Extract-Transform-Load methodology.
class TimeSeriesPipeline:
    def __init__(self, data_path, n_splits=5):
        self.data_path = data_path
        self.data = None
        self.model = None
        self.forecast = None
        self.n_splits = n_splits
    # Load data from Excel file.
    def load_data(self):
        self.data = pd.read_excel(self.data_path)
    # Preprocess data by converting date column to datetime format and removing duplicates.
    def preprocess_data(self, target_column='y', ds_column='ds'):
        self.data[ds_column] = pd.to_datetime(self.data[ds_column])
        self.data = self.data.rename(columns={ds_column: 'ds', target_column: 'y'})

        if self.data.duplicated('ds').any():
            self.data = self.data.drop_duplicates(subset='ds', keep='first')
    # Train Prophet model on training data.
    def train_model(self, train_data):
        self.model = Prophet(seasonality_mode='multiplicative')
        self.model.fit(train_data)
    # Make predictions on test data using trained Prophet model.
    def make_predictions(self, test_data):
        future = self.model.make_future_dataframe(periods=len(test_data), freq='MS')
        self.forecast = self.model.predict(future)
    # Plot the forecasted values to analyze performance visually.
    def plot_forecast(self):
        fig = self.model.plot(self.forecast)
        fig2 = self.model.plot_components(self.forecast)
        plt.show()
    # Evaluate the performance of the trained model on test data.
    def evaluate_model(self, test_data, y_true='y', y_pred='yhat'):
        y_true = test_data[y_true].values
        y_pred = self.forecast[-len(test_data):][y_pred].values
        mse = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true, y_pred)

        return r2, mse, rmse
    # Run the entire pipeline to train, make predictions, and evaluate the model.
    def run_pipeline(self, target_column='y', ds_column='ds'):
        self.load_data()
        self.preprocess_data(target_column=target_column, ds_column=ds_column)

        tscv = TimeSeriesSplit(n_splits=self.n_splits)
        evaluation_scores = []
        for train_index, test_index in tscv.split(self.data):
            train_data, test_data = self.data.iloc[train_index], self.data.iloc[test_index]

            self.train_model(train_data)
            self.make_predictions(test_data)
            self.plot_forecast()
            r2, mse, rmse = self.evaluate_model(test_data, y_true='y', y_pred='yhat')
            evaluation_scores.append((r2, mse, rmse))

        return evaluation_scores
# Save the trained model to a file.
class SaveModel(TimeSeriesPipeline):
    def save_model(self, model_path='house_value_predictor.pkl'):
        joblib.dump(self.model, model_path)


data_path = "output_2.xlsx"
target_column = 'y'
pipeline = SaveModel(data_path)
evaluation_scores = pipeline.run_pipeline(target_column='value', ds_column='time')
pipeline.save_model()

for i, scores in enumerate(evaluation_scores, 1):
    print(f"R2 = {scores[0]}, MSE = {scores[1]}, RMSE = {scores[2]}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-110-99737f719451> in <cell line: 67>()
#      65 target_column = 'y'
#      66 pipeline = SaveModel(data_path)
# ---> 67 evaluation_scores = pipeline.run_pipeline(target_column='value', ds_column='time')
#      68 pipeline.save_model()
#      69
#
# <ipython-input-110-99737f719451> in run_pipeline(self, target_column, ds_column)
#      41     # Run the entire pipeline to train, make predictions, and evaluate the model.
#      42     def run_pipeline(self, target_column='y', ds_column='ds'):
# ---> 43         self.load_data()
#      44         self.preprocess_data(target_column=target_column, ds_column=ds_column)
#      45
#
# <ipython-input-110-99737f719451> in load_data(self)
#       9     # Load data from Excel file.
#      10     def load_data(self):
# ---> 11         self.data = pd.read_excel(self.data_path)
#      12     # Preprocess data by converting date column to datetime format and removing duplicates.
#      13     def preprocess_data(self, target_column='y', ds_column='ds'):
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_2.xlsx'

# %% [markdown]
# Working with the ETL pipeline produces the best results because the training and test sets are split into folds. This provides a cross validation technique. From the plots, the model learns the pattern pretty well even during the 2008 crisis.
#
# Doing a cross validation of every split to get the test scores for the **evaluate model** is however not feasible because of larget training times it takes. It is for this reason that we opt to depend on the visualization of forecasted and real values.

# %% [markdown]
# The prophet model learns the seasonality in the zillow housing data as shown by the plots of every fold. The forecast shows a steady rise of home value for the specified zipcodes.
#
# There is an yearly season where the house values normally peak December.

# %% [markdown]
# ### <b> <span style='color:#16C2D5'>|</span> ZipCodes house prediction</b>
#
# Using the data saved in the csv file **Zipcode_predict.csv**, we set out to investigate how the facebook prophet handles the predictions for the top 30 zipcodes that had houses with higher values.
#
# Just like before, obtaining the scores from the model seems pretty time consuming and may not be feasible at this time.

# %%
# Pipeline to predict the prices of the specified zip codes.
class TimeSeriesPipeline2:
    def __init__(self, data_path, n_splits=5):
        self.data_path = data_path
        self.data = None
        self.model = None
        self.forecast = None
        self.n_splits = n_splits
    # Function to read in the data from the specified file path.
    def load_data(self):
        self.data = pd.read_csv(self.data_path)
    # Function to preprocess the data by converting the date column to datetime format,
    def preprocess_data(self, target_column='y', ds_column='ds'):
        self.data[ds_column] = pd.to_datetime(self.data[ds_column])
        self.data = self.data.rename(columns={ds_column: 'ds', target_column: 'y'})

        if self.data.duplicated('ds').any():
            self.data = self.data.drop_duplicates(subset='ds', keep='first')
    # Function to train the model on the training data.
    def train_model(self, train_data):
        self.model = Prophet(seasonality_mode='multiplicative')
        self.model.fit(train_data)
    # Function to make predictions on the test data.
    def make_predictions(self, test_data):
        future = self.model.make_future_dataframe(periods=len(test_data), freq='MS')
        self.forecast = self.model.predict(future)
    # Function to plot the forecast.
    def plot_forecast(self):
        fig = self.model.plot(self.forecast)
        fig2 = self.model.plot_components(self.forecast)
        plt.show()
    # Function to evaluate the model on the test data.
    def evaluate_model(self, test_data, y_true='y', y_pred='yhat'):
        y_true = test_data[y_true].values
        y_pred = self.forecast[-len(test_data):][y_pred].values
        mse = mean_squared_error(y_true, y_pred)
        rmse = np.sqrt(mse)
        r2 = r2_score(y_true, y_pred)

        return r2, mse, rmse
    # Function to run the entire pipeline.
    def run_pipeline(self, target_column='y', ds_column='ds'):
        self.load_data()
        self.preprocess_data(target_column=target_column, ds_column=ds_column)

        tscv = TimeSeriesSplit(n_splits=self.n_splits)
        evaluation_scores = []
        for train_index, test_index in tscv.split(self.data):
            train_data, test_data = self.data.iloc[train_index], self.data.iloc[test_index]

            self.train_model(train_data)
            self.make_predictions(test_data)
            self.plot_forecast()
            r2, mse, rmse = self.evaluate_model(test_data, y_true='y', y_pred='yhat')
            evaluation_scores.append((r2, mse, rmse))

        return evaluation_scores

# Pipeline to save the trained model.
class SaveModel(TimeSeriesPipeline2):
    def save_model(self, model_path='zipCode_value_predictor.pkl'):
        joblib.dump(self.model, model_path)


data_path = "Zipcode_predict.csv"
target_column = 'y'
pipeline = SaveModel(data_path)
evaluation_scores = pipeline.run_pipeline(target_column='value', ds_column='time')
pipeline.save_model()

# Print the scores for every fold.
for i, scores in enumerate(evaluation_scores, 1):
    print(f"R2 = {scores[0]}, MSE = {scores[1]}, RMSE = {scores[2]}")
# Out:
# 22:02:03 - cmdstanpy - INFO - Chain [1] start processing
# 22:02:03 - cmdstanpy - INFO - Chain [1] done processing
# 22:02:04 - cmdstanpy - INFO - Chain [1] start processing
# 22:02:05 - cmdstanpy - INFO - Chain [1] done processing
# 22:02:06 - cmdstanpy - INFO - Chain [1] start processing
# 22:02:06 - cmdstanpy - INFO - Chain [1] done processing
# 22:02:07 - cmdstanpy - INFO - Chain [1] start processing
# 22:02:08 - cmdstanpy - INFO - Chain [1] done processing
# 22:02:09 - cmdstanpy - INFO - Chain [1] start processing
# 22:02:09 - cmdstanpy - INFO - Chain [1] done processing
# R2 = 0.20914791554348144, MSE = 20013089462.168148, RMSE = 141467.62690512676
# R2 = 0.6229572314809606, MSE = 15377620815.349363, RMSE = 124006.53537354135
# R2 = -21.175234168431437, MSE = 542435185225.2286, RMSE = 736501.992682456
# R2 = -5.47998702403158, MSE = 598754043959.4786, RMSE = 773791.9901107006
# R2 = 0.7366384894333808, MSE = 17449168482.78155, RMSE = 132095.30075964684

# %% [markdown]
# From the plots, what can be deduced is that the model predicts an upward trend of house prices in the specific ZipCodes and in the event of any future crisis, the model has demonstrated its capability of learning the patterns and trends exhibited by the data.

# %% [markdown]
# ### <b><span style='color:#16C2D5'>|</span> Modelling Conclusion</b>
#
# Three models were used specifically the baseline ARIMA model, the auto arima model to find the best pdq combinations, ARIMA models with the best combination sto minimize the AIC scores and finally the prophet model using an ETL pipeline.
#
# The ARIMA model with the lowest AIC scores of **716** was the one of order **0,2,0**. This model gave us the best possible forecasted values to answer our business objective. To find the forecasted value for each zipcode, the forecasted value was averaged.
#
# The use of **TimeSeriesSplit** as a cross validation technique came in handy. This is because the data in the training and test sets is split into folds so as to get a variety of several forecasted value for each zipCode. These forecasted values are then averaged to get the real forecast value for every zipCode.
#
# The **Facebook** model also came in handy because it handles seasonality well especially with the financial crisis in 2008 when house prices tanked. From the plots, the model showed an upward trend of house prices in the zipcodes but each with a different percentage as observed from the forecasted results best ARIMA model. This model captured the seasonality and from the plots, it is clear houses fetch for higher prices between December.
#
# The **facebook model** has an **R2** score of 74% and 73.66%.
#
# In the event of any future financial crisis, the facebook prophet model has parameters which can be adjusted to capture the seasonality and learn the pattern in data. The parameters include:
# * The add_seasonality function
# * Adjusting the fourier order to capture complex seasonality(High fourier orders capture complex patterns)
# * Adding other regressors which may impact on the way the model learns the data.
#
# With all this said, the **Prophet** model has very useful parameters that can be adjusted in the event of any crisis.
#
# The models to forecast both the average monthly house values and the zip codes values have been saved to pickle files and may be used during the production and deployment process because they exhibit great learning patterns.

# %% [markdown]
# ## <div style="padding: 20px;color:white;margin:10;font-size:90%;text-align:left;display:fill;border-radius:10px;overflow:hidden;background-image: url(https://w0.peakpx.com/wallpaper/957/661/HD-wallpaper-white-marble-white-stone-texture-marble-stone-background-white-stone.jpg)"><b><span style='color:black'> 4. Conclusion</span></b> </div>

# %% [markdown]
# 1.The top 5 zipcodes to invest in that guarantee a good **ROI** include:
# * 10021, 10011, 10014, 90210 and 94027.
#
# 2. The market crisis had a severe effect on zipcodes 11217, 90049, 94022, and 94301.
#
# 3. The forecasting model had a R2 score of 74% for forecasting average house values per month. The second model had an accuracy score of 73.66% on the forecasting of house prices for the Regions(ZipCodes) with high house prices.
#
# 4. The metropolitan areas showing higher growth rates are Gleenwood Springs at 200% followed by Brunswick and Panama at 225% and 75% respectively. The ZipCodes(Regions) with high growth rates are 27980(2.5%), 30032(2%), 80216(1.75%) and 89030(1.5%).
